# %% [markdown]
# <a href="https://colab.research.google.com/github/c4bath/cf860/blob/main/APTOS_EfficientNetV2B3_CLAHE_n29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# File Details
#
# Dataset: APTOS w CLAHE preprocessing
#
# Model: EfficientNetV2B3
#
# Adapted from
#
# Transfer learning and fine-tuning
#
# https://www.tensorflow.org/tutorials/images/transfer_learning
#
# coursera - Retinopathy Detection Using Deep Learning
#
#  https://www.coursera.org/learn/retinopathy-detection-using-deep-learning/supplement/em4yb/project-based-course-overview

# %% [markdown]
# # Results - Summary
#
# EfficientNetV2B3
#
# **Initial Training 10 Epochs**
#
# The epoch with the lowest loss is: 8 (Loss: 1.2695)
#
# The epoch with the lowest val_loss is: 10 (Val Loss: 1.3017)
#
# The epoch with the highest accuracy is: 2 (Accuracy: 1.285)
#
# The epoch with the highest validation accuracy is: 1 (Val Accuracy: 1.3278)
#
# The epoch with the highest MCC is: 10 (MCC: 0.0349)
#
# The epoch with the highest validation MCC is: 10 (Val MCC: 0.046)
#
#
#
# **Fine Tuning 45 Epochs**
#
# The epoch with the lowest loss is: 40 (Loss: 0.8823)
#
# The epoch with the lowest val_loss is: 43 (Val Loss: 0.8892)
#
# The epoch with the highest accuracy is: 1 (Accuracy: 1.2656)
#
# The epoch with the highest validation accuracy is: 1 (Val Accuracy: 1.2888)
#
# The epoch with the highest MCC is: 46 (MCC: 0.4986)
#
# The epoch with the highest validation MCC is: 35 (Val MCC: 0.5063)
#
#
#
# **Testing APTOS (Primary)**
#
# Test accuracy : 0.8152027726173401
#
# Test MCC : 0.5170127749443054
#
# ![image.png](data:image/png;base64,...)
#
#
# **Testing Kaggle Eypacs (Secondary)**
#
# Test accuracy : 3.1564080715179443
#
# Test MCC : 0.021782182157039642
#
# ![image.png](data:image/png;base64,...)

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import libraries

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import PIL
from PIL import Image
import seaborn as sns
import plotly
import plotly.graph_objs as go
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import classification_report, confusion_matrix,cohen_kappa_score, matthews_corrcoef
from plotly.offline import iplot, init_notebook_mode
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from IPython.display import display
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Nov 29 19:35:52 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0    31W /  70W |   2801MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
os.listdir('/content/drive/MyDrive/train')
# Out:
# ['Mild', 'Moderate', 'No_DR', 'Proliferative_DR', 'Severe']

# %%
# To have reproducible results
seed = 27

np.random.seed(seed)

tf.random.set_seed(seed)

num_classes = 5

IMG_SIZE = (224,224)

# %%
# Check the number of images in the dataset
train = []
label = []

# os.listdir returns the list of files in the folder, in this case image class names
for i in os.listdir('/content/drive/MyDrive/train'):
  train_class = os.listdir(os.path.join('/content/drive/MyDrive/train', i))
  for j in train_class:
    img = os.path.join('train', i, j)
    train.append(img)
    label.append(i)

print('Number of train images : {} \n'.format(len(train)))
print('Number of train labels : {} \n'.format(len(label)))
# Out:
# Number of train images : 3662
#
# Number of train labels : 3662

# %%
No_images_per_class = []
Class_name = []
for i in os.listdir('/content/drive/MyDrive/train'):
  train_class = os.listdir(os.path.join('/content/drive/MyDrive/train', i))
  No_images_per_class.append(len(train_class))
  Class_name.append(i)
  print('Number of images in {} = {} \n'.format(i, len(train_class)))
# Out:
# Number of images in Mild = 370
#
# Number of images in Moderate = 999
#
# Number of images in No_DR = 1805
#
# Number of images in Proliferative_DR = 295
#
# Number of images in Severe = 193

# %%
retina_df = pd.DataFrame({'Image': train,'Labels': label})
retina_df
# Out:
#                               Image  Labels
# 0       train/Mild/677f087cd697.png    Mild
# 1       train/Mild/ea15a290eb96.png    Mild
# 2       train/Mild/07929d32b5b3.png    Mild
# 3       train/Mild/35d6c4c50072.png    Mild
# 4       train/Mild/a5a2a7003d60.png    Mild
# ...                             ...     ...
# 3657  train/Severe/bb7e0a2544cd.png  Severe
# 3658  train/Severe/38055d8b9f08.png  Severe
# 3659  train/Severe/36b5b3c9fb32.png  Severe
# 3660  train/Severe/51269b77d312.png  Severe
# 3661  train/Severe/fb61230b99dd.png  Severe
#
# [3662 rows x 2 columns]

# %%
# Shuffle the data and split it into training, testing and validation
retina_df = shuffle(retina_df)
train, test = train_test_split(retina_df, test_size = 0.3)
val, test = train_test_split(test, test_size = 0.5)

# %%
train_datagen =  ImageDataGenerator(
    zoom_range=0.15,  # set range for random zoom, changed from 0.15 to 0.3, now changed from 0.3 to 0.45, from 0.45 to 0.6
    fill_mode='constant',
    cval=0.,  # value used for fill_mode = "constant"
    horizontal_flip=True,  # randomly flip images
    vertical_flip=True,# randomly flip images
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    rescale=1./255)


# For test datagenerator, we only normalize the data.
test_datagen = ImageDataGenerator(rescale = 1./255)
val_datagen = ImageDataGenerator(rescale = 1./255)

# %%
base_path = '/content/drive/My Drive/'  # Your base path

train_generator = train_datagen.flow_from_dataframe(
    train,
    directory=base_path,  # Updated directory path
    x_col="Image",
    y_col="Labels",
    target_size=(224, 224),
    color_mode="rgb",
    class_mode="categorical",
    batch_size=32)

validation_generator = val_datagen.flow_from_dataframe(
    val,
    directory=base_path,  # Updated directory path
    x_col="Image",
    y_col="Labels",
    target_size=(224, 224),
    color_mode="rgb",
    class_mode="categorical",
    batch_size=32)

test_generator = test_datagen.flow_from_dataframe(
    test,
    directory=base_path,  # Updated directory path
    x_col="Image",
    y_col="Labels",
    target_size=(224, 224),
    color_mode="rgb",
    class_mode="categorical",
    batch_size=32)
# Out:
# Found 2563 validated image filenames belonging to 5 classes.
# Found 549 validated image filenames belonging to 5 classes.
# Found 550 validated image filenames belonging to 5 classes.

# %%
images, labels = next(test_generator)

# %%
example_image = images[0]

# %%
plt.imshow(example_image)
plt.axis('off')  # To turn off the axis
plt.show()

# %%
# Matthews Correlation Coefficient for multiple classes

class MatthewsCorrelationCoefficient(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="matthews_correlation_coefficient", **kwargs):
        super(MatthewsCorrelationCoefficient, self).__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.confusion_matrix = self.add_weight(
            name="confusion_matrix",
            shape=(num_classes, num_classes),
            initializer="zeros"
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.argmax(y_pred, axis=1)
        y_true = tf.cast(tf.argmax(y_true, axis=1), tf.int32)

        new_confusion_matrix = tf.math.confusion_matrix(y_true, y_pred, self.num_classes)
        new_confusion_matrix = tf.cast(new_confusion_matrix, self.confusion_matrix.dtype)

        return self.confusion_matrix.assign_add(new_confusion_matrix)

    def result(self):
        sum_over_row = tf.reduce_sum(self.confusion_matrix, axis=0)
        sum_over_col = tf.reduce_sum(self.confusion_matrix, axis=1)
        true_positives = tf.linalg.diag_part(self.confusion_matrix)
        predicted_positives = sum_over_row
        actual_positives = sum_over_col
        total_samples = tf.reduce_sum(sum_over_row)

        mcc_numerator = tf.reduce_sum(true_positives * total_samples - predicted_positives * actual_positives)
        mcc_denominator = tf.sqrt(
            (total_samples**2 - tf.reduce_sum(predicted_positives**2)) *
            (total_samples**2 - tf.reduce_sum(actual_positives**2))
        )

        mcc = mcc_numerator / mcc_denominator
        mcc = tf.where(tf.math.is_nan(mcc), tf.zeros_like(mcc), mcc)
        return mcc

    def reset_state(self):
        for s in self.variables:
            s.assign(tf.zeros_like(s))

    def get_config(self):
        config = super(MatthewsCorrelationCoefficient, self).get_config()
        config.update({"num_classes": self.num_classes})
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

mcc_metric = MatthewsCorrelationCoefficient(num_classes)

# %%
base_model = tf.keras.applications.EfficientNetV2B3(input_shape=(224,224,3),
                                               include_top=False,
                                               weights='imagenet')

# %%
image_batch, label_batch = next(iter(train_generator))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 7, 7, 1536)

# %%
base_model.trainable = False

# %%
# Display Model
base_model.summary()
# Out:
# Model: "efficientnetv2-b3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)          0         ['input_3[0][0]']
#
#  normalization_1 (Normaliza  (None, 224, 224, 3)          0         ['rescaling_1[0][0]']
#  tion)
#
#  stem_conv (Conv2D)          (None, 112, 112, 40)         1080      ['normalization_1[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 112, 112, 40)         160       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 112, 112, 40)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 112, 112, 16)         5760      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 112, 112, 16)         64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 112, 112, 16)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1b_project_conv (Conv  (None, 112, 112, 16)         2304      ['block1a_project_activation[0
#  2D)                                                                ][0]']
#
#  block1b_project_bn (BatchN  (None, 112, 112, 16)         64        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 112, 112, 16)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 112, 112, 16)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 112, 112, 16)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_activation[0
#                                                                     ][0]']
#
#  block2a_expand_conv (Conv2  (None, 56, 56, 64)           9216      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 56, 56, 64)           256       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 56, 56, 64)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 56, 56, 40)           2560      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 56, 56, 40)           160       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 56, 56, 160)          57600     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 56, 56, 160)          640       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 56, 56, 160)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 56, 56, 40)           6400      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 56, 56, 40)           160       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 56, 56, 40)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 56, 56, 40)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 56, 56, 160)          57600     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 56, 56, 160)          640       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 56, 56, 160)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 56, 56, 40)           6400      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 56, 56, 40)           160       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 56, 56, 40)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 56, 56, 40)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 28, 28, 160)          57600     ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 28, 28, 160)          640       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 28, 28, 160)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 28, 28, 56)           8960      ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 28, 28, 56)           224       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 28, 28, 224)          112896    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 28, 28, 224)          896       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 28, 28, 224)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 28, 28, 56)           12544     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 28, 28, 56)           224       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 28, 28, 56)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 28, 28, 56)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 28, 28, 224)          112896    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 28, 28, 224)          896       ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 28, 28, 224)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 28, 28, 56)           12544     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 28, 28, 56)           224       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 28, 28, 56)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 28, 28, 56)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 28, 28, 224)          12544     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 28, 28, 224)          896       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 28, 28, 224)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 14, 14, 224)          2016      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 14, 14, 224)          896       ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 14, 14, 224)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 224)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 224)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 14)             3150      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 224)            3360      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 14, 14, 224)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 14, 14, 112)          25088     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 14, 14, 112)          448       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 14, 14, 448)          50176     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 14, 14, 448)          1792      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 14, 14, 448)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 14, 14, 448)          4032      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 14, 14, 448)          1792      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 14, 14, 448)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 448)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 448)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 28)             12572     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 448)            12992     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 14, 14, 448)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 14, 14, 112)          50176     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 14, 14, 112)          448       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 14, 14, 112)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 14, 14, 112)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 14, 14, 448)          50176     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 14, 14, 448)          1792      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 14, 14, 448)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 14, 14, 448)          4032      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 14, 14, 448)          1792      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 14, 14, 448)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 448)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 448)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 28)             12572     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 448)            12992     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 14, 14, 448)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 14, 14, 112)          50176     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 14, 14, 112)          448       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 14, 14, 112)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 14, 14, 112)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 14, 14, 448)          50176     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 14, 14, 448)          1792      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 14, 14, 448)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 14, 14, 448)          4032      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 14, 14, 448)          1792      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 14, 14, 448)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 448)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 448)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 28)             12572     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 448)            12992     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 14, 14, 448)          0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 14, 14, 112)          50176     ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 14, 14, 112)          448       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 14, 14, 112)          0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 14, 14, 112)          0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2  (None, 14, 14, 448)          50176     ['block4d_add[0][0]']
#  D)
#
#  block4e_expand_bn (BatchNo  (None, 14, 14, 448)          1792      ['block4e_expand_conv[0][0]']
#  rmalization)
#
#  block4e_expand_activation   (None, 14, 14, 448)          0         ['block4e_expand_bn[0][0]']
#  (Activation)
#
#  block4e_dwconv2 (Depthwise  (None, 14, 14, 448)          4032      ['block4e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4e_bn (BatchNormaliza  (None, 14, 14, 448)          1792      ['block4e_dwconv2[0][0]']
#  tion)
#
#  block4e_activation (Activa  (None, 14, 14, 448)          0         ['block4e_bn[0][0]']
#  tion)
#
#  block4e_se_squeeze (Global  (None, 448)                  0         ['block4e_activation[0][0]']
#  AveragePooling2D)
#
#  block4e_se_reshape (Reshap  (None, 1, 1, 448)            0         ['block4e_se_squeeze[0][0]']
#  e)
#
#  block4e_se_reduce (Conv2D)  (None, 1, 1, 28)             12572     ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)  (None, 1, 1, 448)            12992     ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multipl  (None, 14, 14, 448)          0         ['block4e_activation[0][0]',
#  y)                                                                  'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv  (None, 14, 14, 112)          50176     ['block4e_se_excite[0][0]']
#  2D)
#
#  block4e_project_bn (BatchN  (None, 14, 14, 112)          448       ['block4e_project_conv[0][0]']
#  ormalization)
#
#  block4e_drop (Dropout)      (None, 14, 14, 112)          0         ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)           (None, 14, 14, 112)          0         ['block4e_drop[0][0]',
#                                                                      'block4d_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 14, 14, 672)          75264     ['block4e_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 14, 14, 672)          2688      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 14, 14, 672)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 14, 14, 672)          6048      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 14, 14, 672)          2688      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 14, 14, 672)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 672)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 14, 14, 672)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 14, 14, 136)          91392     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 14, 14, 136)          544       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 14, 14, 816)          110976    ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 14, 14, 816)          3264      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 14, 14, 816)          0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv2 (Depthwise  (None, 14, 14, 816)          7344      ['block5b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5b_bn (BatchNormaliza  (None, 14, 14, 816)          3264      ['block5b_dwconv2[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 14, 14, 816)          0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 816)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 816)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 34)             27778     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 816)            28560     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 14, 14, 816)          0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 14, 14, 136)          110976    ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 14, 14, 136)          544       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 14, 14, 136)          0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 14, 14, 136)          0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 14, 14, 816)          110976    ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 14, 14, 816)          3264      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 14, 14, 816)          0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv2 (Depthwise  (None, 14, 14, 816)          7344      ['block5c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5c_bn (BatchNormaliza  (None, 14, 14, 816)          3264      ['block5c_dwconv2[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 14, 14, 816)          0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 816)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 816)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 34)             27778     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 816)            28560     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 14, 14, 816)          0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 14, 14, 136)          110976    ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 14, 14, 136)          544       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 14, 14, 136)          0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 14, 14, 136)          0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block5d_expand_conv (Conv2  (None, 14, 14, 816)          110976    ['block5c_add[0][0]']
#  D)
#
#  block5d_expand_bn (BatchNo  (None, 14, 14, 816)          3264      ['block5d_expand_conv[0][0]']
#  rmalization)
# ...
#  block6i_se_squeeze (Global  (None, 1392)                 0         ['block6i_activation[0][0]']
#  AveragePooling2D)
#
#  block6i_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6i_se_squeeze[0][0]']
#  e)
#
#  block6i_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multipl  (None, 7, 7, 1392)           0         ['block6i_activation[0][0]',
#  y)                                                                  'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv  (None, 7, 7, 232)            322944    ['block6i_se_excite[0][0]']
#  2D)
#
#  block6i_project_bn (BatchN  (None, 7, 7, 232)            928       ['block6i_project_conv[0][0]']
#  ormalization)
#
#  block6i_drop (Dropout)      (None, 7, 7, 232)            0         ['block6i_project_bn[0][0]']
#
#  block6i_add (Add)           (None, 7, 7, 232)            0         ['block6i_drop[0][0]',
#                                                                      'block6h_add[0][0]']
#
#  block6j_expand_conv (Conv2  (None, 7, 7, 1392)           322944    ['block6i_add[0][0]']
#  D)
#
#  block6j_expand_bn (BatchNo  (None, 7, 7, 1392)           5568      ['block6j_expand_conv[0][0]']
#  rmalization)
#
#  block6j_expand_activation   (None, 7, 7, 1392)           0         ['block6j_expand_bn[0][0]']
#  (Activation)
#
#  block6j_dwconv2 (Depthwise  (None, 7, 7, 1392)           12528     ['block6j_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6j_bn (BatchNormaliza  (None, 7, 7, 1392)           5568      ['block6j_dwconv2[0][0]']
#  tion)
#
#  block6j_activation (Activa  (None, 7, 7, 1392)           0         ['block6j_bn[0][0]']
#  tion)
#
#  block6j_se_squeeze (Global  (None, 1392)                 0         ['block6j_activation[0][0]']
#  AveragePooling2D)
#
#  block6j_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6j_se_squeeze[0][0]']
#  e)
#
#  block6j_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6j_se_reshape[0][0]']
#
#  block6j_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6j_se_reduce[0][0]']
#
#  block6j_se_excite (Multipl  (None, 7, 7, 1392)           0         ['block6j_activation[0][0]',
#  y)                                                                  'block6j_se_expand[0][0]']
#
#  block6j_project_conv (Conv  (None, 7, 7, 232)            322944    ['block6j_se_excite[0][0]']
#  2D)
#
#  block6j_project_bn (BatchN  (None, 7, 7, 232)            928       ['block6j_project_conv[0][0]']
#  ormalization)
#
#  block6j_drop (Dropout)      (None, 7, 7, 232)            0         ['block6j_project_bn[0][0]']
#
#  block6j_add (Add)           (None, 7, 7, 232)            0         ['block6j_drop[0][0]',
#                                                                      'block6i_add[0][0]']
#
#  block6k_expand_conv (Conv2  (None, 7, 7, 1392)           322944    ['block6j_add[0][0]']
#  D)
#
#  block6k_expand_bn (BatchNo  (None, 7, 7, 1392)           5568      ['block6k_expand_conv[0][0]']
#  rmalization)
#
#  block6k_expand_activation   (None, 7, 7, 1392)           0         ['block6k_expand_bn[0][0]']
#  (Activation)
#
#  block6k_dwconv2 (Depthwise  (None, 7, 7, 1392)           12528     ['block6k_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6k_bn (BatchNormaliza  (None, 7, 7, 1392)           5568      ['block6k_dwconv2[0][0]']
#  tion)
#
#  block6k_activation (Activa  (None, 7, 7, 1392)           0         ['block6k_bn[0][0]']
#  tion)
#
#  block6k_se_squeeze (Global  (None, 1392)                 0         ['block6k_activation[0][0]']
#  AveragePooling2D)
#
#  block6k_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6k_se_squeeze[0][0]']
#  e)
#
#  block6k_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6k_se_reshape[0][0]']
#
#  block6k_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6k_se_reduce[0][0]']
#
#  block6k_se_excite (Multipl  (None, 7, 7, 1392)           0         ['block6k_activation[0][0]',
#  y)                                                                  'block6k_se_expand[0][0]']
#
#  block6k_project_conv (Conv  (None, 7, 7, 232)            322944    ['block6k_se_excite[0][0]']
#  2D)
#
#  block6k_project_bn (BatchN  (None, 7, 7, 232)            928       ['block6k_project_conv[0][0]']
#  ormalization)
#
#  block6k_drop (Dropout)      (None, 7, 7, 232)            0         ['block6k_project_bn[0][0]']
#
#  block6k_add (Add)           (None, 7, 7, 232)            0         ['block6k_drop[0][0]',
#                                                                      'block6j_add[0][0]']
#
#  block6l_expand_conv (Conv2  (None, 7, 7, 1392)           322944    ['block6k_add[0][0]']
#  D)
#
#  block6l_expand_bn (BatchNo  (None, 7, 7, 1392)           5568      ['block6l_expand_conv[0][0]']
#  rmalization)
#
#  block6l_expand_activation   (None, 7, 7, 1392)           0         ['block6l_expand_bn[0][0]']
#  (Activation)
#
#  block6l_dwconv2 (Depthwise  (None, 7, 7, 1392)           12528     ['block6l_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6l_bn (BatchNormaliza  (None, 7, 7, 1392)           5568      ['block6l_dwconv2[0][0]']
#  tion)
#
#  block6l_activation (Activa  (None, 7, 7, 1392)           0         ['block6l_bn[0][0]']
#  tion)
#
#  block6l_se_squeeze (Global  (None, 1392)                 0         ['block6l_activation[0][0]']
#  AveragePooling2D)
#
#  block6l_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6l_se_squeeze[0][0]']
#  e)
#
#  block6l_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multipl  (None, 7, 7, 1392)           0         ['block6l_activation[0][0]',
#  y)                                                                  'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv  (None, 7, 7, 232)            322944    ['block6l_se_excite[0][0]']
#  2D)
#
#  block6l_project_bn (BatchN  (None, 7, 7, 232)            928       ['block6l_project_conv[0][0]']
#  ormalization)
#
#  block6l_drop (Dropout)      (None, 7, 7, 232)            0         ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)           (None, 7, 7, 232)            0         ['block6l_drop[0][0]',
#                                                                      'block6k_add[0][0]']
#
#  top_conv (Conv2D)           (None, 7, 7, 1536)           356352    ['block6l_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 7, 7, 1536)           6144      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 7, 7, 1536)           0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 12930622 (49.33 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 12930622 (49.33 MB)
# __________________________________________________________________________________________________

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 1536)

# %%
prediction_layer = tf.keras.layers.Dense(5, activation='softmax')
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 5)

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
#x = data_augmentation(inputs) already augmented in train_generator
#x = preprocess_input(x) already rescaled in train and val_generator
x = base_model(inputs, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetv2-b3 (Functio  (None, 7, 7, 1536)        12930622
#  nal)
#
#  global_average_pooling2d_1  (None, 1536)              0
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1536)              0
#
#  dense_1 (Dense)             (None, 5)                 7685
#
# =================================================================
# Total params: 12938307 (49.36 MB)
# Trainable params: 7685 (30.02 KB)
# Non-trainable params: 12930622 (49.33 MB)
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 2

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              metrics=[tf.keras.metrics.CategoricalCrossentropy(name='accuracy'),mcc_metric])

# %%
#apply early stopping to exit training if validation loss is not decreasing even after certain epochs (patience)
earlystopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)

#save the best model with lowest validation loss
checkpointer = ModelCheckpoint(filepath="/content/drive/MyDrive/drweights/EffNetweights1433.hdf5", verbose=1, save_best_only=True)

# %%
initial_epochs = 10

# %%
history = model.fit(train_generator, steps_per_epoch = train_generator.n // 32, epochs = initial_epochs, validation_data= validation_generator, validation_steps= validation_generator.n // 32, callbacks=[checkpointer , earlystopping])
# Out:
# Epoch 1/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2842 - accuracy: 1.2842 - matthews_correlation_coefficient: 0.0000e+00
# Epoch 1: val_loss improved from inf to 1.32776, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 80/80 [==============================] - 60s 620ms/step - loss: 1.2842 - accuracy: 1.2842 - matthews_correlation_coefficient: 0.0000e+00 - val_loss: 1.3278 - val_accuracy: 1.3278 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 2/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2850 - accuracy: 1.2850 - matthews_correlation_coefficient: 0.0000e+00
# Epoch 2: val_loss improved from 1.32776 to 1.32172, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 49s 620ms/step - loss: 1.2850 - accuracy: 1.2850 - matthews_correlation_coefficient: 0.0000e+00 - val_loss: 1.3217 - val_accuracy: 1.3217 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 3/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2807 - accuracy: 1.2807 - matthews_correlation_coefficient: 0.0000e+00
# Epoch 3: val_loss improved from 1.32172 to 1.31940, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 48s 605ms/step - loss: 1.2807 - accuracy: 1.2807 - matthews_correlation_coefficient: 0.0000e+00 - val_loss: 1.3194 - val_accuracy: 1.3194 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 4/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2785 - accuracy: 1.2785 - matthews_correlation_coefficient: 0.0055
# Epoch 4: val_loss improved from 1.31940 to 1.31825, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 47s 590ms/step - loss: 1.2785 - accuracy: 1.2785 - matthews_correlation_coefficient: 0.0055 - val_loss: 1.3183 - val_accuracy: 1.3183 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 5/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2813 - accuracy: 1.2813 - matthews_correlation_coefficient: 0.0039
# Epoch 5: val_loss improved from 1.31825 to 1.31412, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 46s 579ms/step - loss: 1.2813 - accuracy: 1.2813 - matthews_correlation_coefficient: 0.0039 - val_loss: 1.3141 - val_accuracy: 1.3141 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 6/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2762 - accuracy: 1.2762 - matthews_correlation_coefficient: 0.0039
# Epoch 6: val_loss did not improve from 1.31412
# 80/80 [==============================] - 47s 584ms/step - loss: 1.2762 - accuracy: 1.2762 - matthews_correlation_coefficient: 0.0039 - val_loss: 1.3142 - val_accuracy: 1.3142 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 7/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2727 - accuracy: 1.2727 - matthews_correlation_coefficient: 0.0234
# Epoch 7: val_loss improved from 1.31412 to 1.31206, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 46s 575ms/step - loss: 1.2727 - accuracy: 1.2727 - matthews_correlation_coefficient: 0.0234 - val_loss: 1.3121 - val_accuracy: 1.3121 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 8/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2695 - accuracy: 1.2695 - matthews_correlation_coefficient: 0.0234
# Epoch 8: val_loss improved from 1.31206 to 1.31108, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 48s 606ms/step - loss: 1.2695 - accuracy: 1.2695 - matthews_correlation_coefficient: 0.0234 - val_loss: 1.3111 - val_accuracy: 1.3111 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 9/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2770 - accuracy: 1.2770 - matthews_correlation_coefficient: 0.0290
# Epoch 9: val_loss improved from 1.31108 to 1.30814, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 48s 596ms/step - loss: 1.2770 - accuracy: 1.2770 - matthews_correlation_coefficient: 0.0290 - val_loss: 1.3081 - val_accuracy: 1.3081 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 10/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2717 - accuracy: 1.2717 - matthews_correlation_coefficient: 0.0349
# Epoch 10: val_loss improved from 1.30814 to 1.30172, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 48s 605ms/step - loss: 1.2717 - accuracy: 1.2717 - matthews_correlation_coefficient: 0.0349 - val_loss: 1.3017 - val_accuracy: 1.3017 - val_matthews_correlation_coefficient: 0.0460

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

matthews_correlation_coefficient = history.history['matthews_correlation_coefficient']
val_matthews_correlation_coefficient = history.history['val_matthews_correlation_coefficient']

fig, axs = plt.subplots(3, 1, figsize=(5, 15))

plt.subplot(3, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.xlabel('epoch')

plt.subplot(3, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')


plt.subplot(3, 1, 3)
plt.plot(matthews_correlation_coefficient, label='Training MCC')
plt.plot(val_matthews_correlation_coefficient, label='Validation MCC')
plt.legend(loc='upper right')
plt.ylabel('MCC')
plt.ylim([0,1.0])
plt.title('Training and Validation MCC')
plt.xlabel('epoch')
plt.show()

# %%
# Loss
min_loss_index = np.argmin(history.history['loss'])
min_loss_value = round(history.history['loss'][min_loss_index], 4)
print(f'The epoch with the lowest loss is: {min_loss_index + 1} (Loss: {min_loss_value})')

# Validation Loss
min_val_loss_index = np.argmin(history.history['val_loss'])
min_val_loss_value = round(history.history['val_loss'][min_val_loss_index], 4)
print(f'The epoch with the lowest val_loss is: {min_val_loss_index + 1} (Val Loss: {min_val_loss_value})')

# Accuracy
max_accuracy_index = np.argmax(history.history['accuracy'])
max_accuracy_value = round(history.history['accuracy'][max_accuracy_index], 4)
print(f'The epoch with the highest accuracy is: {max_accuracy_index + 1} (Accuracy: {max_accuracy_value})')

# Validation Accuracy
max_val_acc_index = np.argmax(history.history['val_accuracy'])
max_val_acc_value = round(history.history['val_accuracy'][max_val_acc_index], 4)
print(f'The epoch with the highest validation accuracy is: {max_val_acc_index + 1} (Val Accuracy: {max_val_acc_value})')

# Matthews Correlation Coefficient (MCC)
max_mcc_index = np.argmax(history.history['matthews_correlation_coefficient'])
max_mcc_value = round(history.history['matthews_correlation_coefficient'][max_mcc_index], 4)
print(f'The epoch with the highest MCC is: {max_mcc_index + 1} (MCC: {max_mcc_value})')

# Validation MCC
max_val_mcc_index = np.argmax(history.history['val_matthews_correlation_coefficient'])
max_val_mcc_value = round(history.history['val_matthews_correlation_coefficient'][max_val_mcc_index], 4)
print(f'The epoch with the highest validation MCC is: {max_val_mcc_index + 1} (Val MCC: {max_val_mcc_value})')

best_epoch_model = max_val_mcc_index + 1
# Out:
# The epoch with the lowest loss is: 8 (Loss: 1.2695)
# The epoch with the lowest val_loss is: 10 (Val Loss: 1.3017)
# The epoch with the highest accuracy is: 2 (Accuracy: 1.285)
# The epoch with the highest validation accuracy is: 1 (Val Accuracy: 1.3278)
# The epoch with the highest MCC is: 10 (MCC: 0.0349)
# The epoch with the highest validation MCC is: 10 (Val MCC: 0.046)

# %%
base_model.trainable = True

# %%
# Total layers in the base model
print("Number of layers in the base model: ", len(base_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False
# Out:
# Number of layers in the base model:  409

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate/10),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              metrics=[tf.keras.metrics.CategoricalCrossentropy(name='accuracy'),mcc_metric])

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetv2-b3 (Functio  (None, 7, 7, 1536)        12930622
#  nal)
#
#  global_average_pooling2d_1  (None, 1536)              0
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1536)              0
#
#  dense_1 (Dense)             (None, 5)                 7685
#
# =================================================================
# Total params: 12938307 (49.36 MB)
# Trainable params: 11992821 (45.75 MB)
# Non-trainable params: 945486 (3.61 MB)
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 272

# %%
fine_tune_epochs = 45
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_generator, steps_per_epoch = train_generator.n // 32, epochs = total_epochs, initial_epoch=history.epoch[-1], validation_data= validation_generator, validation_steps= validation_generator.n // 32, callbacks=[checkpointer , earlystopping])
# Out:
# Epoch 10/55
# 80/80 [==============================] - ETA: 0s - loss: 1.2656 - accuracy: 1.2656 - matthews_correlation_coefficient: 0.0919
# Epoch 10: val_loss improved from 1.30172 to 1.28877, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 105s 689ms/step - loss: 1.2656 - accuracy: 1.2656 - matthews_correlation_coefficient: 0.0919 - val_loss: 1.2888 - val_accuracy: 1.2888 - val_matthews_correlation_coefficient: 0.2330
# Epoch 11/55
# 80/80 [==============================] - ETA: 0s - loss: 1.2237 - accuracy: 1.2237 - matthews_correlation_coefficient: 0.1488
# Epoch 11: val_loss improved from 1.28877 to 1.20388, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 56s 701ms/step - loss: 1.2237 - accuracy: 1.2237 - matthews_correlation_coefficient: 0.1488 - val_loss: 1.2039 - val_accuracy: 1.2039 - val_matthews_correlation_coefficient: 0.3120
# Epoch 12/55
# 80/80 [==============================] - ETA: 0s - loss: 1.1793 - accuracy: 1.1793 - matthews_correlation_coefficient: 0.2466
# Epoch 12: val_loss improved from 1.20388 to 1.18317, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 55s 685ms/step - loss: 1.1793 - accuracy: 1.1793 - matthews_correlation_coefficient: 0.2466 - val_loss: 1.1832 - val_accuracy: 1.1832 - val_matthews_correlation_coefficient: 0.3405
# Epoch 13/55
# 80/80 [==============================] - ETA: 0s - loss: 1.1445 - accuracy: 1.1445 - matthews_correlation_coefficient: 0.2894
# Epoch 13: val_loss improved from 1.18317 to 1.15025, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 55s 688ms/step - loss: 1.1445 - accuracy: 1.1445 - matthews_correlation_coefficient: 0.2894 - val_loss: 1.1502 - val_accuracy: 1.1502 - val_matthews_correlation_coefficient: 0.3583
# Epoch 14/55
# 80/80 [==============================] - ETA: 0s - loss: 1.1373 - accuracy: 1.1373 - matthews_correlation_coefficient: 0.3098
# Epoch 14: val_loss improved from 1.15025 to 1.14201, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 55s 692ms/step - loss: 1.1373 - accuracy: 1.1373 - matthews_correlation_coefficient: 0.3098 - val_loss: 1.1420 - val_accuracy: 1.1420 - val_matthews_correlation_coefficient: 0.3382
# Epoch 15/55
# 80/80 [==============================] - ETA: 0s - loss: 1.1289 - accuracy: 1.1289 - matthews_correlation_coefficient: 0.3059
# Epoch 15: val_loss did not improve from 1.14201
# 80/80 [==============================] - 50s 622ms/step - loss: 1.1289 - accuracy: 1.1289 - matthews_correlation_coefficient: 0.3059 - val_loss: 1.1851 - val_accuracy: 1.1851 - val_matthews_correlation_coefficient: 0.3685
# Epoch 16/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0717 - accuracy: 1.0717 - matthews_correlation_coefficient: 0.3645
# Epoch 16: val_loss improved from 1.14201 to 1.00860, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 55s 692ms/step - loss: 1.0717 - accuracy: 1.0717 - matthews_correlation_coefficient: 0.3645 - val_loss: 1.0086 - val_accuracy: 1.0086 - val_matthews_correlation_coefficient: 0.4331
# Epoch 17/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0572 - accuracy: 1.0572 - matthews_correlation_coefficient: 0.3686
# Epoch 17: val_loss improved from 1.00860 to 0.97994, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 55s 684ms/step - loss: 1.0572 - accuracy: 1.0572 - matthews_correlation_coefficient: 0.3686 - val_loss: 0.9799 - val_accuracy: 0.9799 - val_matthews_correlation_coefficient: 0.4430
# Epoch 18/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0650 - accuracy: 1.0650 - matthews_correlation_coefficient: 0.3678
# Epoch 18: val_loss did not improve from 0.97994
# 80/80 [==============================] - 52s 643ms/step - loss: 1.0650 - accuracy: 1.0650 - matthews_correlation_coefficient: 0.3678 - val_loss: 0.9853 - val_accuracy: 0.9853 - val_matthews_correlation_coefficient: 0.4348
# Epoch 19/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0239 - accuracy: 1.0239 - matthews_correlation_coefficient: 0.3939
# Epoch 19: val_loss did not improve from 0.97994
# 80/80 [==============================] - 51s 640ms/step - loss: 1.0239 - accuracy: 1.0239 - matthews_correlation_coefficient: 0.3939 - val_loss: 0.9831 - val_accuracy: 0.9831 - val_matthews_correlation_coefficient: 0.4607
# Epoch 20/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0104 - accuracy: 1.0104 - matthews_correlation_coefficient: 0.4112
# Epoch 20: val_loss improved from 0.97994 to 0.95704, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 55s 692ms/step - loss: 1.0104 - accuracy: 1.0104 - matthews_correlation_coefficient: 0.4112 - val_loss: 0.9570 - val_accuracy: 0.9570 - val_matthews_correlation_coefficient: 0.4493
# Epoch 21/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0230 - accuracy: 1.0230 - matthews_correlation_coefficient: 0.4012
# Epoch 21: val_loss did not improve from 0.95704
# 80/80 [==============================] - 52s 645ms/step - loss: 1.0230 - accuracy: 1.0230 - matthews_correlation_coefficient: 0.4012 - val_loss: 0.9824 - val_accuracy: 0.9824 - val_matthews_correlation_coefficient: 0.4554
# Epoch 22/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9965 - accuracy: 0.9965 - matthews_correlation_coefficient: 0.4249
# Epoch 22: val_loss improved from 0.95704 to 0.93320, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 55s 691ms/step - loss: 0.9965 - accuracy: 0.9965 - matthews_correlation_coefficient: 0.4249 - val_loss: 0.9332 - val_accuracy: 0.9332 - val_matthews_correlation_coefficient: 0.4683
# Epoch 23/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9806 - accuracy: 0.9806 - matthews_correlation_coefficient: 0.4355
# Epoch 23: val_loss did not improve from 0.93320
# 80/80 [==============================] - 52s 648ms/step - loss: 0.9806 - accuracy: 0.9806 - matthews_correlation_coefficient: 0.4355 - val_loss: 0.9385 - val_accuracy: 0.9385 - val_matthews_correlation_coefficient: 0.4676
# Epoch 24/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9840 - accuracy: 0.9840 - matthews_correlation_coefficient: 0.4346
# Epoch 24: val_loss did not improve from 0.93320
# 80/80 [==============================] - 50s 624ms/step - loss: 0.9840 - accuracy: 0.9840 - matthews_correlation_coefficient: 0.4346 - val_loss: 0.9967 - val_accuracy: 0.9967 - val_matthews_correlation_coefficient: 0.4707
# Epoch 25/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9772 - accuracy: 0.9772 - matthews_correlation_coefficient: 0.4311
# Epoch 25: val_loss improved from 0.93320 to 0.93258, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 53s 669ms/step - loss: 0.9772 - accuracy: 0.9772 - matthews_correlation_coefficient: 0.4311 - val_loss: 0.9326 - val_accuracy: 0.9326 - val_matthews_correlation_coefficient: 0.4749
# Epoch 26/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9755 - accuracy: 0.9755 - matthews_correlation_coefficient: 0.4296
# Epoch 26: val_loss did not improve from 0.93258
# 80/80 [==============================] - 50s 620ms/step - loss: 0.9755 - accuracy: 0.9755 - matthews_correlation_coefficient: 0.4296 - val_loss: 0.9685 - val_accuracy: 0.9685 - val_matthews_correlation_coefficient: 0.4459
# Epoch 27/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9929 - accuracy: 0.9929 - matthews_correlation_coefficient: 0.4299
# Epoch 27: val_loss did not improve from 0.93258
# 80/80 [==============================] - 50s 617ms/step - loss: 0.9929 - accuracy: 0.9929 - matthews_correlation_coefficient: 0.4299 - val_loss: 0.9463 - val_accuracy: 0.9463 - val_matthews_correlation_coefficient: 0.4847
# Epoch 28/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9910 - accuracy: 0.9910 - matthews_correlation_coefficient: 0.4208
# Epoch 28: val_loss did not improve from 0.93258
# 80/80 [==============================] - 51s 638ms/step - loss: 0.9910 - accuracy: 0.9910 - matthews_correlation_coefficient: 0.4208 - val_loss: 0.9568 - val_accuracy: 0.9568 - val_matthews_correlation_coefficient: 0.4497
# Epoch 29/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9703 - accuracy: 0.9703 - matthews_correlation_coefficient: 0.4384
# Epoch 29: val_loss improved from 0.93258 to 0.93107, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 54s 673ms/step - loss: 0.9703 - accuracy: 0.9703 - matthews_correlation_coefficient: 0.4384 - val_loss: 0.9311 - val_accuracy: 0.9311 - val_matthews_correlation_coefficient: 0.4614
# Epoch 30/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9719 - accuracy: 0.9719 - matthews_correlation_coefficient: 0.4412
# Epoch 30: val_loss did not improve from 0.93107
# 80/80 [==============================] - 50s 626ms/step - loss: 0.9719 - accuracy: 0.9719 - matthews_correlation_coefficient: 0.4412 - val_loss: 0.9724 - val_accuracy: 0.9724 - val_matthews_correlation_coefficient: 0.4787
# Epoch 31/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9944 - accuracy: 0.9944 - matthews_correlation_coefficient: 0.4195
# Epoch 31: val_loss did not improve from 0.93107
# 80/80 [==============================] - 49s 617ms/step - loss: 0.9944 - accuracy: 0.9944 - matthews_correlation_coefficient: 0.4195 - val_loss: 0.9465 - val_accuracy: 0.9465 - val_matthews_correlation_coefficient: 0.4875
# Epoch 32/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9596 - accuracy: 0.9596 - matthews_correlation_coefficient: 0.4449
# Epoch 32: val_loss did not improve from 0.93107
# 80/80 [==============================] - 50s 627ms/step - loss: 0.9596 - accuracy: 0.9596 - matthews_correlation_coefficient: 0.4449 - val_loss: 0.9373 - val_accuracy: 0.9373 - val_matthews_correlation_coefficient: 0.4891
# Epoch 33/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9498 - accuracy: 0.9498 - matthews_correlation_coefficient: 0.4578
# Epoch 33: val_loss improved from 0.93107 to 0.91256, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 54s 672ms/step - loss: 0.9498 - accuracy: 0.9498 - matthews_correlation_coefficient: 0.4578 - val_loss: 0.9126 - val_accuracy: 0.9126 - val_matthews_correlation_coefficient: 0.4724
# Epoch 34/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0114 - accuracy: 1.0114 - matthews_correlation_coefficient: 0.4092
# Epoch 34: val_loss did not improve from 0.91256
# 80/80 [==============================] - 50s 620ms/step - loss: 1.0114 - accuracy: 1.0114 - matthews_correlation_coefficient: 0.4092 - val_loss: 0.9336 - val_accuracy: 0.9336 - val_matthews_correlation_coefficient: 0.4847
# Epoch 35/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9233 - accuracy: 0.9233 - matthews_correlation_coefficient: 0.4683
# Epoch 35: val_loss improved from 0.91256 to 0.90111, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 55s 689ms/step - loss: 0.9233 - accuracy: 0.9233 - matthews_correlation_coefficient: 0.4683 - val_loss: 0.9011 - val_accuracy: 0.9011 - val_matthews_correlation_coefficient: 0.4719
# Epoch 36/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9358 - accuracy: 0.9358 - matthews_correlation_coefficient: 0.4520
# Epoch 36: val_loss did not improve from 0.90111
# 80/80 [==============================] - 50s 625ms/step - loss: 0.9358 - accuracy: 0.9358 - matthews_correlation_coefficient: 0.4520 - val_loss: 0.9043 - val_accuracy: 0.9043 - val_matthews_correlation_coefficient: 0.4799
# Epoch 37/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9262 - accuracy: 0.9262 - matthews_correlation_coefficient: 0.4615
# Epoch 37: val_loss did not improve from 0.90111
# 80/80 [==============================] - 50s 623ms/step - loss: 0.9262 - accuracy: 0.9262 - matthews_correlation_coefficient: 0.4615 - val_loss: 0.9279 - val_accuracy: 0.9279 - val_matthews_correlation_coefficient: 0.4597
# Epoch 38/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9188 - accuracy: 0.9188 - matthews_correlation_coefficient: 0.4736
# Epoch 38: val_loss did not improve from 0.90111
# 80/80 [==============================] - 50s 616ms/step - loss: 0.9188 - accuracy: 0.9188 - matthews_correlation_coefficient: 0.4736 - val_loss: 0.9055 - val_accuracy: 0.9055 - val_matthews_correlation_coefficient: 0.4621
# Epoch 39/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9270 - accuracy: 0.9270 - matthews_correlation_coefficient: 0.4606
# Epoch 39: val_loss did not improve from 0.90111
# 80/80 [==============================] - 50s 624ms/step - loss: 0.9270 - accuracy: 0.9270 - matthews_correlation_coefficient: 0.4606 - val_loss: 0.9465 - val_accuracy: 0.9465 - val_matthews_correlation_coefficient: 0.4548
# Epoch 40/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9313 - accuracy: 0.9313 - matthews_correlation_coefficient: 0.4706
# Epoch 40: val_loss improved from 0.90111 to 0.89666, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 55s 693ms/step - loss: 0.9313 - accuracy: 0.9313 - matthews_correlation_coefficient: 0.4706 - val_loss: 0.8967 - val_accuracy: 0.8967 - val_matthews_correlation_coefficient: 0.4626
# Epoch 41/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9170 - accuracy: 0.9170 - matthews_correlation_coefficient: 0.4726
# Epoch 41: val_loss did not improve from 0.89666
# 80/80 [==============================] - 50s 619ms/step - loss: 0.9170 - accuracy: 0.9170 - matthews_correlation_coefficient: 0.4726 - val_loss: 0.9323 - val_accuracy: 0.9323 - val_matthews_correlation_coefficient: 0.4825
# Epoch 42/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9204 - accuracy: 0.9204 - matthews_correlation_coefficient: 0.4693
# Epoch 42: val_loss did not improve from 0.89666
# 80/80 [==============================] - 50s 627ms/step - loss: 0.9204 - accuracy: 0.9204 - matthews_correlation_coefficient: 0.4693 - val_loss: 0.9175 - val_accuracy: 0.9175 - val_matthews_correlation_coefficient: 0.4778
# Epoch 43/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9054 - accuracy: 0.9054 - matthews_correlation_coefficient: 0.4797
# Epoch 43: val_loss did not improve from 0.89666
# 80/80 [==============================] - 50s 619ms/step - loss: 0.9054 - accuracy: 0.9054 - matthews_correlation_coefficient: 0.4797 - val_loss: 0.9184 - val_accuracy: 0.9184 - val_matthews_correlation_coefficient: 0.4696
# Epoch 44/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9059 - accuracy: 0.9059 - matthews_correlation_coefficient: 0.4732
# Epoch 44: val_loss did not improve from 0.89666
# 80/80 [==============================] - 49s 615ms/step - loss: 0.9059 - accuracy: 0.9059 - matthews_correlation_coefficient: 0.4732 - val_loss: 0.9136 - val_accuracy: 0.9136 - val_matthews_correlation_coefficient: 0.5063
# Epoch 45/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9125 - accuracy: 0.9125 - matthews_correlation_coefficient: 0.4773
# Epoch 45: val_loss improved from 0.89666 to 0.89479, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 56s 696ms/step - loss: 0.9125 - accuracy: 0.9125 - matthews_correlation_coefficient: 0.4773 - val_loss: 0.8948 - val_accuracy: 0.8948 - val_matthews_correlation_coefficient: 0.4633
# Epoch 46/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9248 - accuracy: 0.9248 - matthews_correlation_coefficient: 0.4749
# Epoch 46: val_loss improved from 0.89479 to 0.89316, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 56s 701ms/step - loss: 0.9248 - accuracy: 0.9248 - matthews_correlation_coefficient: 0.4749 - val_loss: 0.8932 - val_accuracy: 0.8932 - val_matthews_correlation_coefficient: 0.4769
# Epoch 47/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9333 - accuracy: 0.9333 - matthews_correlation_coefficient: 0.4812
# Epoch 47: val_loss did not improve from 0.89316
# 80/80 [==============================] - 50s 621ms/step - loss: 0.9333 - accuracy: 0.9333 - matthews_correlation_coefficient: 0.4812 - val_loss: 0.9006 - val_accuracy: 0.9006 - val_matthews_correlation_coefficient: 0.4652
# Epoch 48/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9029 - accuracy: 0.9029 - matthews_correlation_coefficient: 0.4814
# Epoch 48: val_loss did not improve from 0.89316
# 80/80 [==============================] - 50s 624ms/step - loss: 0.9029 - accuracy: 0.9029 - matthews_correlation_coefficient: 0.4814 - val_loss: 0.9312 - val_accuracy: 0.9312 - val_matthews_correlation_coefficient: 0.4495
# Epoch 49/55
# 80/80 [==============================] - ETA: 0s - loss: 0.8823 - accuracy: 0.8823 - matthews_correlation_coefficient: 0.4814
# Epoch 49: val_loss did not improve from 0.89316
# 80/80 [==============================] - 49s 615ms/step - loss: 0.8823 - accuracy: 0.8823 - matthews_correlation_coefficient: 0.4814 - val_loss: 0.9134 - val_accuracy: 0.9134 - val_matthews_correlation_coefficient: 0.4713
# Epoch 50/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9100 - accuracy: 0.9100 - matthews_correlation_coefficient: 0.4818
# Epoch 50: val_loss did not improve from 0.89316
# 80/80 [==============================] - 50s 623ms/step - loss: 0.9100 - accuracy: 0.9100 - matthews_correlation_coefficient: 0.4818 - val_loss: 0.9721 - val_accuracy: 0.9721 - val_matthews_correlation_coefficient: 0.4443
# Epoch 51/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9154 - accuracy: 0.9154 - matthews_correlation_coefficient: 0.4660
# Epoch 51: val_loss did not improve from 0.89316
# 80/80 [==============================] - 50s 625ms/step - loss: 0.9154 - accuracy: 0.9154 - matthews_correlation_coefficient: 0.4660 - val_loss: 0.9463 - val_accuracy: 0.9463 - val_matthews_correlation_coefficient: 0.4442
# Epoch 52/55
# 80/80 [==============================] - ETA: 0s - loss: 0.8845 - accuracy: 0.8845 - matthews_correlation_coefficient: 0.4915
# Epoch 52: val_loss improved from 0.89316 to 0.88920, saving model to /content/drive/MyDrive/drweights/EffNetweights1433.hdf5
# 80/80 [==============================] - 56s 698ms/step - loss: 0.8845 - accuracy: 0.8845 - matthews_correlation_coefficient: 0.4915 - val_loss: 0.8892 - val_accuracy: 0.8892 - val_matthews_correlation_coefficient: 0.4714
# Epoch 53/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9216 - accuracy: 0.9216 - matthews_correlation_coefficient: 0.4763
# Epoch 53: val_loss did not improve from 0.88920
# 80/80 [==============================] - 52s 641ms/step - loss: 0.9216 - accuracy: 0.9216 - matthews_correlation_coefficient: 0.4763 - val_loss: 0.9362 - val_accuracy: 0.9362 - val_matthews_correlation_coefficient: 0.4578
# Epoch 54/55
# 80/80 [==============================] - ETA: 0s - loss: 0.8986 - accuracy: 0.8986 - matthews_correlation_coefficient: 0.4777
# Epoch 54: val_loss did not improve from 0.88920
# 80/80 [==============================] - 50s 627ms/step - loss: 0.8986 - accuracy: 0.8986 - matthews_correlation_coefficient: 0.4777 - val_loss: 0.9089 - val_accuracy: 0.9089 - val_matthews_correlation_coefficient: 0.4659
# Epoch 55/55
# 80/80 [==============================] - ETA: 0s - loss: 0.8843 - accuracy: 0.8843 - matthews_correlation_coefficient: 0.4986
# Epoch 55: val_loss did not improve from 0.88920
# 80/80 [==============================] - 51s 631ms/step - loss: 0.8843 - accuracy: 0.8843 - matthews_correlation_coefficient: 0.4986 - val_loss: 0.8918 - val_accuracy: 0.8918 - val_matthews_correlation_coefficient: 0.4642

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

matthews_correlation_coefficient += history_fine.history['matthews_correlation_coefficient']
val_matthews_correlation_coefficient += history_fine.history['val_matthews_correlation_coefficient']

# %%
fig, axs = plt.subplots(3, 1, figsize=(5, 15))

plt.subplot(3, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.8, 1])
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('epoch')

plt.subplot(3, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')

plt.subplot(3, 1, 3)
plt.plot(matthews_correlation_coefficient, label='Training MCC')
plt.plot(val_matthews_correlation_coefficient, label='Validation MCC')
plt.ylim([0, 1.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation MCC')
plt.xlabel('epoch')

plt.show()

# %%
# Loss
min_loss_index = np.argmin(history_fine.history['loss'])
min_loss_value = round(history_fine.history['loss'][min_loss_index], 4)
print(f'The epoch with the lowest loss is: {min_loss_index + 1} (Loss: {min_loss_value})')

# Validation Loss
min_val_loss_index = np.argmin(history_fine.history['val_loss'])
min_val_loss_value = round(history_fine.history['val_loss'][min_val_loss_index], 4)
print(f'The epoch with the lowest val_loss is: {min_val_loss_index + 1} (Val Loss: {min_val_loss_value})')

# Accuracy
max_accuracy_index = np.argmax(history_fine.history['accuracy'])
max_accuracy_value = round(history_fine.history['accuracy'][max_accuracy_index], 4)
print(f'The epoch with the highest accuracy is: {max_accuracy_index + 1} (Accuracy: {max_accuracy_value})')

# Validation Accuracy
max_val_acc_index = np.argmax(history_fine.history['val_accuracy'])
max_val_acc_value = round(history_fine.history['val_accuracy'][max_val_acc_index], 4)
print(f'The epoch with the highest validation accuracy is: {max_val_acc_index + 1} (Val Accuracy: {max_val_acc_value})')

# Matthews Correlation Coefficient (MCC)
max_mcc_index = np.argmax(history_fine.history['matthews_correlation_coefficient'])
max_mcc_value = round(history_fine.history['matthews_correlation_coefficient'][max_mcc_index], 4)
print(f'The epoch with the highest MCC is: {max_mcc_index + 1} (MCC: {max_mcc_value})')

# Validation MCC
max_val_mcc_index = np.argmax(history_fine.history['val_matthews_correlation_coefficient'])
max_val_mcc_value = round(history_fine.history['val_matthews_correlation_coefficient'][max_val_mcc_index], 4)
print(f'The epoch with the highest validation MCC is: {max_val_mcc_index + 1} (Val MCC: {max_val_mcc_value})')

best_epoch_model = max_val_mcc_index + 1
# Out:
# The epoch with the lowest loss is: 40 (Loss: 0.8823)
# The epoch with the lowest val_loss is: 43 (Val Loss: 0.8892)
# The epoch with the highest accuracy is: 1 (Accuracy: 1.2656)
# The epoch with the highest validation accuracy is: 1 (Val Accuracy: 1.2888)
# The epoch with the highest MCC is: 46 (MCC: 0.4986)
# The epoch with the highest validation MCC is: 35 (Val MCC: 0.5063)

# %%
model.load_weights("/content/drive/MyDrive/drweights/EffNetweights1433.hdf5")

# %%
loss, accuracy, matthews_correlation_coefficient = model.evaluate(test_generator)
print('Test accuracy :', accuracy, 'Test MCC :', matthews_correlation_coefficient)
# Out:
# 18/18 [==============================] - 208s 12s/step - loss: 0.8152 - accuracy: 0.8152 - matthews_correlation_coefficient: 0.5170
# Test accuracy : 0.8152027726173401 Test MCC : 0.5170127749443054

# %%
# Predict with the model on the test set
predictions = model.predict(test_generator)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Retrieve the true labels from the test generator
true_labels = test_generator.classes

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=test_generator.class_indices.keys(),zero_division=0)
print("Classification Report:")
print(report)

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 18/18 [==============================] - 5s 133ms/step
# Classification Report:
#                   precision    recall  f1-score   support
#
#             Mild       0.00      0.00      0.00        55
#         Moderate       0.28      0.44      0.34       164
#            No_DR       0.46      0.52      0.49       259
# Proliferative_DR       0.00      0.00      0.00        45
#           Severe       0.00      0.00      0.00        27
#
#         accuracy                           0.38       550
#        macro avg       0.15      0.19      0.17       550
#     weighted avg       0.30      0.38      0.33       550
#
# Confusion Matrix:
# [[  0  23  32   0   0]
#  [  0  72  92   0   0]
#  [  0 124 135   0   0]
#  [  0  24  21   0   0]
#  [  0  13  14   0   0]]

# %%
conf_matrix = confusion_matrix(true_labels, predicted_labels)
class_names = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative DR']
# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Evaluate on Kaggle test dataset

# %%
# Load kaggle test dataset
images_path = '/content/drive/MyDrive/minitestarrays/mtestimages.npy'
labels_path = '/content/drive/MyDrive/minitestarrays/mtestlabels.npy'

# Load the arrays
mtestimages = np.load(images_path)
mtestlabels = np.load(labels_path)

# %%
loss, accuracy, matthews_correlation_coefficient = model.evaluate(mtestimages,mtestlabels)
print('Test accuracy :', accuracy, 'Test MCC :', matthews_correlation_coefficient)
# Out:
# 32/32 [==============================] - 4s 109ms/step - loss: 3.1564 - accuracy: 3.1564 - matthews_correlation_coefficient: 0.0218
# Test accuracy : 3.1564080715179443 Test MCC : 0.021782182157039642

# %%
predictionsk = model.predict(mtestimages)
predicted_classesk = np.argmax(predictionsk, axis=1)

#predicted_classesk = np.argmax(predictionsk, axis=1)
actual_classesk = np.argmax(mtestlabels, axis=1)
# Out:
# 32/32 [==============================] - 5s 92ms/step

# %%
reportk = classification_report(actual_classesk, predicted_classesk, target_names=['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative DR'],zero_division=0)
print(reportk)

# Print confusion matrix
cmk = confusion_matrix(actual_classesk, predicted_classesk)
print('Confusion Matrix:')
print(cmk)
# Out:
#                   precision    recall  f1-score   support
#
#            No DR       0.00      0.00      0.00       735
#             Mild       0.12      0.10      0.11        70
#         Moderate       0.15      0.95      0.26       151
#           Severe       0.00      0.00      0.00        25
# Proliferative DR       0.00      0.00      0.00        20
#
#         accuracy                           0.15      1001
#        macro avg       0.05      0.21      0.07      1001
#     weighted avg       0.03      0.15      0.05      1001
#
# Confusion Matrix:
# [[  0  42 693   0   0]
#  [  0   7  63   0   0]
#  [  0   7 144   0   0]
#  [  0   0  25   0   0]
#  [  0   3  17   0   0]]

# %%
cmk = confusion_matrix(actual_classesk, predicted_classesk)
class_names = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative DR']
# Plotting
plt.figure(figsize=(10, 7))
sns.heatmap(cmk, annot=True, fmt='g', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
