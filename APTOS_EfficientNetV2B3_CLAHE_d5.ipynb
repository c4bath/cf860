# %% [markdown]
# <a href="https://colab.research.google.com/github/c4bath/cf860/blob/main/APTOS_EfficientNetV2B3_CLAHE_d5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# File Details
#
# Dataset: APTOS w CLAHE preprocessing
#
# Model: EfficientNetV2B3
#
# Adapted from
#
# Transfer learning and fine-tuning
#
# https://www.tensorflow.org/tutorials/images/transfer_learning
#
# coursera - Retinopathy Detection Using Deep Learning
#
#  https://www.coursera.org/learn/retinopathy-detection-using-deep-learning/supplement/em4yb/project-based-course-overview

# %% [markdown]
# # Results - Summary
#
# EfficientNetV2B3
#
# **Initial Training 10 Epochs**
#
# The epoch with the lowest loss is: 8 (Loss: 1.2695)
#
# The epoch with the lowest val_loss is: 10 (Val Loss: 1.3017)
#
# The epoch with the highest accuracy is: 2 (Accuracy: 1.285)
#
# The epoch with the highest validation accuracy is: 1 (Val Accuracy: 1.3278)
#
# The epoch with the highest MCC is: 10 (MCC: 0.0349)
#
# The epoch with the highest validation MCC is: 10 (Val MCC: 0.046)
#
#
#
# **Fine Tuning 45 Epochs**
#
# The epoch with the lowest loss is: 40 (Loss: 0.8823)
#
# The epoch with the lowest val_loss is: 43 (Val Loss: 0.8892)
#
# The epoch with the highest accuracy is: 1 (Accuracy: 1.2656)
#
# The epoch with the highest validation accuracy is: 1 (Val Accuracy: 1.2888)
#
# The epoch with the highest MCC is: 46 (MCC: 0.4986)
#
# The epoch with the highest validation MCC is: 35 (Val MCC: 0.5063)
#
#
#
# **Testing APTOS (Primary)**
#
# Test accuracy : 0.8152027726173401
#
# Test MCC : 0.5170127749443054
#
# ![image.png](data:image/png;base64,...)
#
#
# **Testing Kaggle Eypacs (Secondary)**
#
# Test accuracy : 3.1564080715179443
#
# Test MCC : 0.021782182157039642
#
# ![image.png](data:image/png;base64,...)

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import libraries

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import PIL
from PIL import Image
import seaborn as sns
import plotly
import plotly.graph_objs as go
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import classification_report, confusion_matrix,cohen_kappa_score, matthews_corrcoef
from plotly.offline import iplot, init_notebook_mode
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from IPython.display import display
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Dec  6 01:18:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
os.listdir('/content/drive/MyDrive/train')
# Out:
# ['Mild', 'Moderate', 'No_DR', 'Proliferative_DR', 'Severe']

# %%
# To have reproducible results
seed = 27

np.random.seed(seed)

tf.random.set_seed(seed)

num_classes = 5

IMG_SIZE = (224,224)

# %%
# Check the number of images in the dataset
train = []
label = []

# os.listdir returns the list of files in the folder, in this case image class names
for i in os.listdir('/content/drive/MyDrive/train'):
  train_class = os.listdir(os.path.join('/content/drive/MyDrive/train', i))
  for j in train_class:
    img = os.path.join('train', i, j)
    train.append(img)
    label.append(i)

print('Number of train images : {} \n'.format(len(train)))
print('Number of train labels : {} \n'.format(len(label)))
# Out:
# Number of train images : 3662
#
# Number of train labels : 3662

# %%
No_images_per_class = []
Class_name = []
for i in os.listdir('/content/drive/MyDrive/train'):
  train_class = os.listdir(os.path.join('/content/drive/MyDrive/train', i))
  No_images_per_class.append(len(train_class))
  Class_name.append(i)
  print('Number of images in {} = {} \n'.format(i, len(train_class)))
# Out:
# Number of images in Mild = 370
#
# Number of images in Moderate = 999
#
# Number of images in No_DR = 1805
#
# Number of images in Proliferative_DR = 295
#
# Number of images in Severe = 193

# %%
retina_df = pd.DataFrame({'Image': train,'Labels': label})
retina_df
# Out:
#                               Image  Labels
# 0       train/Mild/677f087cd697.png    Mild
# 1       train/Mild/ea15a290eb96.png    Mild
# 2       train/Mild/07929d32b5b3.png    Mild
# 3       train/Mild/35d6c4c50072.png    Mild
# 4       train/Mild/a5a2a7003d60.png    Mild
# ...                             ...     ...
# 3657  train/Severe/bb7e0a2544cd.png  Severe
# 3658  train/Severe/38055d8b9f08.png  Severe
# 3659  train/Severe/36b5b3c9fb32.png  Severe
# 3660  train/Severe/51269b77d312.png  Severe
# 3661  train/Severe/fb61230b99dd.png  Severe
#
# [3662 rows x 2 columns]

# %%
# Shuffle the data and split it into training, testing and validation
retina_df = shuffle(retina_df)
train, test = train_test_split(retina_df, test_size = 0.3)
val, test = train_test_split(test, test_size = 0.5)

# %%
train_datagen =  ImageDataGenerator(
    zoom_range=0.15,  # set range for random zoom, changed from 0.15 to 0.3, now changed from 0.3 to 0.45, from 0.45 to 0.6
    fill_mode='constant',
    cval=0.,  # value used for fill_mode = "constant"
    horizontal_flip=True,  # randomly flip images
    vertical_flip=True,# randomly flip images
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    rescale=1./255)


# For test datagenerator, we only normalize the data.
test_datagen = ImageDataGenerator(rescale = 1./255)
val_datagen = ImageDataGenerator(rescale = 1./255)

# %%
base_path = '/content/drive/My Drive/'  # Your base path

train_generator = train_datagen.flow_from_dataframe(
    train,
    directory=base_path,  # Updated directory path
    x_col="Image",
    y_col="Labels",
    target_size=(224, 224),
    color_mode="rgb",
    class_mode="categorical",
    batch_size=32)

validation_generator = val_datagen.flow_from_dataframe(
    val,
    directory=base_path,  # Updated directory path
    x_col="Image",
    y_col="Labels",
    target_size=(224, 224),
    color_mode="rgb",
    class_mode="categorical",
    batch_size=32)

test_generator = test_datagen.flow_from_dataframe(
    test,
    directory=base_path,  # Updated directory path
    x_col="Image",
    y_col="Labels",
    target_size=(224, 224),
    color_mode="rgb",
    class_mode="categorical",
    batch_size=32)
# Out:
# Found 2563 validated image filenames belonging to 5 classes.
# Found 549 validated image filenames belonging to 5 classes.
# Found 550 validated image filenames belonging to 5 classes.

# %%
images, labels = next(test_generator)

# %%
example_image = images[0]

# %%
plt.imshow(example_image)
plt.axis('off')  # To turn off the axis
plt.show()

# %%
# Matthews Correlation Coefficient for multiple classes

class MatthewsCorrelationCoefficient(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name="matthews_correlation_coefficient", **kwargs):
        super(MatthewsCorrelationCoefficient, self).__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.confusion_matrix = self.add_weight(
            name="confusion_matrix",
            shape=(num_classes, num_classes),
            initializer="zeros"
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.argmax(y_pred, axis=1)
        y_true = tf.cast(tf.argmax(y_true, axis=1), tf.int32)

        new_confusion_matrix = tf.math.confusion_matrix(y_true, y_pred, self.num_classes)
        new_confusion_matrix = tf.cast(new_confusion_matrix, self.confusion_matrix.dtype)

        return self.confusion_matrix.assign_add(new_confusion_matrix)

    def result(self):
        sum_over_row = tf.reduce_sum(self.confusion_matrix, axis=0)
        sum_over_col = tf.reduce_sum(self.confusion_matrix, axis=1)
        true_positives = tf.linalg.diag_part(self.confusion_matrix)
        predicted_positives = sum_over_row
        actual_positives = sum_over_col
        total_samples = tf.reduce_sum(sum_over_row)

        mcc_numerator = tf.reduce_sum(true_positives * total_samples - predicted_positives * actual_positives)
        mcc_denominator = tf.sqrt(
            (total_samples**2 - tf.reduce_sum(predicted_positives**2)) *
            (total_samples**2 - tf.reduce_sum(actual_positives**2))
        )

        mcc = mcc_numerator / mcc_denominator
        mcc = tf.where(tf.math.is_nan(mcc), tf.zeros_like(mcc), mcc)
        return mcc

    def reset_state(self):
        for s in self.variables:
            s.assign(tf.zeros_like(s))

    def get_config(self):
        config = super(MatthewsCorrelationCoefficient, self).get_config()
        config.update({"num_classes": self.num_classes})
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

mcc_metric = MatthewsCorrelationCoefficient(num_classes)

# %%
base_model = tf.keras.applications.EfficientNetV2B3(input_shape=(224,224,3),
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b3_notop.h5
# 52606240/52606240 [==============================] - 0s 0us/step

# %%
image_batch, label_batch = next(iter(train_generator))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 7, 7, 1536)

# %%
base_model.trainable = False

# %%
# Display Model
base_model.summary()
# Out:
# Model: "efficientnetv2-b3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 224, 224, 3)          0         ['rescaling[0][0]']
#  on)
#
#  stem_conv (Conv2D)          (None, 112, 112, 40)         1080      ['normalization[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 112, 112, 40)         160       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 112, 112, 40)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 112, 112, 16)         5760      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 112, 112, 16)         64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 112, 112, 16)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1b_project_conv (Conv  (None, 112, 112, 16)         2304      ['block1a_project_activation[0
#  2D)                                                                ][0]']
#
#  block1b_project_bn (BatchN  (None, 112, 112, 16)         64        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 112, 112, 16)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 112, 112, 16)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 112, 112, 16)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_activation[0
#                                                                     ][0]']
#
#  block2a_expand_conv (Conv2  (None, 56, 56, 64)           9216      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 56, 56, 64)           256       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 56, 56, 64)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 56, 56, 40)           2560      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 56, 56, 40)           160       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 56, 56, 160)          57600     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 56, 56, 160)          640       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 56, 56, 160)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 56, 56, 40)           6400      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 56, 56, 40)           160       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 56, 56, 40)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 56, 56, 40)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 56, 56, 160)          57600     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 56, 56, 160)          640       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 56, 56, 160)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 56, 56, 40)           6400      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 56, 56, 40)           160       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 56, 56, 40)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 56, 56, 40)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 28, 28, 160)          57600     ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 28, 28, 160)          640       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 28, 28, 160)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 28, 28, 56)           8960      ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 28, 28, 56)           224       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 28, 28, 224)          112896    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 28, 28, 224)          896       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 28, 28, 224)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 28, 28, 56)           12544     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 28, 28, 56)           224       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 28, 28, 56)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 28, 28, 56)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 28, 28, 224)          112896    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 28, 28, 224)          896       ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 28, 28, 224)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 28, 28, 56)           12544     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 28, 28, 56)           224       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 28, 28, 56)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 28, 28, 56)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 28, 28, 224)          12544     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 28, 28, 224)          896       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 28, 28, 224)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 14, 14, 224)          2016      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 14, 14, 224)          896       ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 14, 14, 224)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 224)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 224)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 14)             3150      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 224)            3360      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 14, 14, 224)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 14, 14, 112)          25088     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 14, 14, 112)          448       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 14, 14, 448)          50176     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 14, 14, 448)          1792      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 14, 14, 448)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 14, 14, 448)          4032      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 14, 14, 448)          1792      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 14, 14, 448)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 448)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 448)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 28)             12572     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 448)            12992     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 14, 14, 448)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 14, 14, 112)          50176     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 14, 14, 112)          448       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 14, 14, 112)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 14, 14, 112)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 14, 14, 448)          50176     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 14, 14, 448)          1792      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 14, 14, 448)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 14, 14, 448)          4032      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 14, 14, 448)          1792      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 14, 14, 448)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 448)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 448)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 28)             12572     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 448)            12992     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 14, 14, 448)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 14, 14, 112)          50176     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 14, 14, 112)          448       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 14, 14, 112)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 14, 14, 112)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 14, 14, 448)          50176     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 14, 14, 448)          1792      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 14, 14, 448)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 14, 14, 448)          4032      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 14, 14, 448)          1792      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 14, 14, 448)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 448)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 448)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 28)             12572     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 448)            12992     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 14, 14, 448)          0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 14, 14, 112)          50176     ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 14, 14, 112)          448       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 14, 14, 112)          0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 14, 14, 112)          0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2  (None, 14, 14, 448)          50176     ['block4d_add[0][0]']
#  D)
#
#  block4e_expand_bn (BatchNo  (None, 14, 14, 448)          1792      ['block4e_expand_conv[0][0]']
#  rmalization)
#
#  block4e_expand_activation   (None, 14, 14, 448)          0         ['block4e_expand_bn[0][0]']
#  (Activation)
#
#  block4e_dwconv2 (Depthwise  (None, 14, 14, 448)          4032      ['block4e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4e_bn (BatchNormaliza  (None, 14, 14, 448)          1792      ['block4e_dwconv2[0][0]']
#  tion)
#
#  block4e_activation (Activa  (None, 14, 14, 448)          0         ['block4e_bn[0][0]']
#  tion)
#
#  block4e_se_squeeze (Global  (None, 448)                  0         ['block4e_activation[0][0]']
#  AveragePooling2D)
#
#  block4e_se_reshape (Reshap  (None, 1, 1, 448)            0         ['block4e_se_squeeze[0][0]']
#  e)
#
#  block4e_se_reduce (Conv2D)  (None, 1, 1, 28)             12572     ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)  (None, 1, 1, 448)            12992     ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multipl  (None, 14, 14, 448)          0         ['block4e_activation[0][0]',
#  y)                                                                  'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv  (None, 14, 14, 112)          50176     ['block4e_se_excite[0][0]']
#  2D)
#
#  block4e_project_bn (BatchN  (None, 14, 14, 112)          448       ['block4e_project_conv[0][0]']
#  ormalization)
#
#  block4e_drop (Dropout)      (None, 14, 14, 112)          0         ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)           (None, 14, 14, 112)          0         ['block4e_drop[0][0]',
#                                                                      'block4d_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 14, 14, 672)          75264     ['block4e_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 14, 14, 672)          2688      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 14, 14, 672)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 14, 14, 672)          6048      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 14, 14, 672)          2688      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 14, 14, 672)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 672)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 14, 14, 672)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 14, 14, 136)          91392     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 14, 14, 136)          544       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 14, 14, 816)          110976    ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 14, 14, 816)          3264      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 14, 14, 816)          0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv2 (Depthwise  (None, 14, 14, 816)          7344      ['block5b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5b_bn (BatchNormaliza  (None, 14, 14, 816)          3264      ['block5b_dwconv2[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 14, 14, 816)          0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 816)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 816)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 34)             27778     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 816)            28560     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 14, 14, 816)          0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 14, 14, 136)          110976    ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 14, 14, 136)          544       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 14, 14, 136)          0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 14, 14, 136)          0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 14, 14, 816)          110976    ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 14, 14, 816)          3264      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 14, 14, 816)          0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv2 (Depthwise  (None, 14, 14, 816)          7344      ['block5c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5c_bn (BatchNormaliza  (None, 14, 14, 816)          3264      ['block5c_dwconv2[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 14, 14, 816)          0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 816)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 816)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 34)             27778     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 816)            28560     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 14, 14, 816)          0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 14, 14, 136)          110976    ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 14, 14, 136)          544       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 14, 14, 136)          0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 14, 14, 136)          0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block5d_expand_conv (Conv2  (None, 14, 14, 816)          110976    ['block5c_add[0][0]']
#  D)
#
#  block5d_expand_bn (BatchNo  (None, 14, 14, 816)          3264      ['block5d_expand_conv[0][0]']
#  rmalization)
# ...
#  block6i_se_squeeze (Global  (None, 1392)                 0         ['block6i_activation[0][0]']
#  AveragePooling2D)
#
#  block6i_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6i_se_squeeze[0][0]']
#  e)
#
#  block6i_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multipl  (None, 7, 7, 1392)           0         ['block6i_activation[0][0]',
#  y)                                                                  'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv  (None, 7, 7, 232)            322944    ['block6i_se_excite[0][0]']
#  2D)
#
#  block6i_project_bn (BatchN  (None, 7, 7, 232)            928       ['block6i_project_conv[0][0]']
#  ormalization)
#
#  block6i_drop (Dropout)      (None, 7, 7, 232)            0         ['block6i_project_bn[0][0]']
#
#  block6i_add (Add)           (None, 7, 7, 232)            0         ['block6i_drop[0][0]',
#                                                                      'block6h_add[0][0]']
#
#  block6j_expand_conv (Conv2  (None, 7, 7, 1392)           322944    ['block6i_add[0][0]']
#  D)
#
#  block6j_expand_bn (BatchNo  (None, 7, 7, 1392)           5568      ['block6j_expand_conv[0][0]']
#  rmalization)
#
#  block6j_expand_activation   (None, 7, 7, 1392)           0         ['block6j_expand_bn[0][0]']
#  (Activation)
#
#  block6j_dwconv2 (Depthwise  (None, 7, 7, 1392)           12528     ['block6j_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6j_bn (BatchNormaliza  (None, 7, 7, 1392)           5568      ['block6j_dwconv2[0][0]']
#  tion)
#
#  block6j_activation (Activa  (None, 7, 7, 1392)           0         ['block6j_bn[0][0]']
#  tion)
#
#  block6j_se_squeeze (Global  (None, 1392)                 0         ['block6j_activation[0][0]']
#  AveragePooling2D)
#
#  block6j_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6j_se_squeeze[0][0]']
#  e)
#
#  block6j_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6j_se_reshape[0][0]']
#
#  block6j_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6j_se_reduce[0][0]']
#
#  block6j_se_excite (Multipl  (None, 7, 7, 1392)           0         ['block6j_activation[0][0]',
#  y)                                                                  'block6j_se_expand[0][0]']
#
#  block6j_project_conv (Conv  (None, 7, 7, 232)            322944    ['block6j_se_excite[0][0]']
#  2D)
#
#  block6j_project_bn (BatchN  (None, 7, 7, 232)            928       ['block6j_project_conv[0][0]']
#  ormalization)
#
#  block6j_drop (Dropout)      (None, 7, 7, 232)            0         ['block6j_project_bn[0][0]']
#
#  block6j_add (Add)           (None, 7, 7, 232)            0         ['block6j_drop[0][0]',
#                                                                      'block6i_add[0][0]']
#
#  block6k_expand_conv (Conv2  (None, 7, 7, 1392)           322944    ['block6j_add[0][0]']
#  D)
#
#  block6k_expand_bn (BatchNo  (None, 7, 7, 1392)           5568      ['block6k_expand_conv[0][0]']
#  rmalization)
#
#  block6k_expand_activation   (None, 7, 7, 1392)           0         ['block6k_expand_bn[0][0]']
#  (Activation)
#
#  block6k_dwconv2 (Depthwise  (None, 7, 7, 1392)           12528     ['block6k_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6k_bn (BatchNormaliza  (None, 7, 7, 1392)           5568      ['block6k_dwconv2[0][0]']
#  tion)
#
#  block6k_activation (Activa  (None, 7, 7, 1392)           0         ['block6k_bn[0][0]']
#  tion)
#
#  block6k_se_squeeze (Global  (None, 1392)                 0         ['block6k_activation[0][0]']
#  AveragePooling2D)
#
#  block6k_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6k_se_squeeze[0][0]']
#  e)
#
#  block6k_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6k_se_reshape[0][0]']
#
#  block6k_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6k_se_reduce[0][0]']
#
#  block6k_se_excite (Multipl  (None, 7, 7, 1392)           0         ['block6k_activation[0][0]',
#  y)                                                                  'block6k_se_expand[0][0]']
#
#  block6k_project_conv (Conv  (None, 7, 7, 232)            322944    ['block6k_se_excite[0][0]']
#  2D)
#
#  block6k_project_bn (BatchN  (None, 7, 7, 232)            928       ['block6k_project_conv[0][0]']
#  ormalization)
#
#  block6k_drop (Dropout)      (None, 7, 7, 232)            0         ['block6k_project_bn[0][0]']
#
#  block6k_add (Add)           (None, 7, 7, 232)            0         ['block6k_drop[0][0]',
#                                                                      'block6j_add[0][0]']
#
#  block6l_expand_conv (Conv2  (None, 7, 7, 1392)           322944    ['block6k_add[0][0]']
#  D)
#
#  block6l_expand_bn (BatchNo  (None, 7, 7, 1392)           5568      ['block6l_expand_conv[0][0]']
#  rmalization)
#
#  block6l_expand_activation   (None, 7, 7, 1392)           0         ['block6l_expand_bn[0][0]']
#  (Activation)
#
#  block6l_dwconv2 (Depthwise  (None, 7, 7, 1392)           12528     ['block6l_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6l_bn (BatchNormaliza  (None, 7, 7, 1392)           5568      ['block6l_dwconv2[0][0]']
#  tion)
#
#  block6l_activation (Activa  (None, 7, 7, 1392)           0         ['block6l_bn[0][0]']
#  tion)
#
#  block6l_se_squeeze (Global  (None, 1392)                 0         ['block6l_activation[0][0]']
#  AveragePooling2D)
#
#  block6l_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block6l_se_squeeze[0][0]']
#  e)
#
#  block6l_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multipl  (None, 7, 7, 1392)           0         ['block6l_activation[0][0]',
#  y)                                                                  'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv  (None, 7, 7, 232)            322944    ['block6l_se_excite[0][0]']
#  2D)
#
#  block6l_project_bn (BatchN  (None, 7, 7, 232)            928       ['block6l_project_conv[0][0]']
#  ormalization)
#
#  block6l_drop (Dropout)      (None, 7, 7, 232)            0         ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)           (None, 7, 7, 232)            0         ['block6l_drop[0][0]',
#                                                                      'block6k_add[0][0]']
#
#  top_conv (Conv2D)           (None, 7, 7, 1536)           356352    ['block6l_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 7, 7, 1536)           6144      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 7, 7, 1536)           0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 12930622 (49.33 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 12930622 (49.33 MB)
# __________________________________________________________________________________________________

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 1536)

# %%
prediction_layer = tf.keras.layers.Dense(5, activation='softmax')
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 5)

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
#x = data_augmentation(inputs) already augmented in train_generator
#x = preprocess_input(x) already rescaled in train and val_generator
x = base_model(inputs, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetv2-b3 (Functio  (None, 7, 7, 1536)        12930622
#  nal)
#
#  global_average_pooling2d (  (None, 1536)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1536)              0
#
#  dense (Dense)               (None, 5)                 7685
#
# =================================================================
# Total params: 12938307 (49.36 MB)
# Trainable params: 7685 (30.02 KB)
# Non-trainable params: 12930622 (49.33 MB)
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 2

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              metrics=[tf.keras.metrics.CategoricalCrossentropy(name='accuracy'),mcc_metric])

# %%
#apply early stopping to exit training if validation loss is not decreasing even after certain epochs (patience)
earlystopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)

#save the best model with lowest validation loss
checkpointer = ModelCheckpoint(filepath="/content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5", verbose=1, save_best_only=True)

# %%
initial_epochs = 10

# %%
history = model.fit(train_generator, steps_per_epoch = train_generator.n // 32, epochs = initial_epochs, validation_data= validation_generator, validation_steps= validation_generator.n // 32, callbacks=[checkpointer , earlystopping])
# Out:
# Epoch 1/10
# 80/80 [==============================] - ETA: 0s - loss: 1.3783 - accuracy: 1.3783 - matthews_correlation_coefficient: -0.0102
# Epoch 1: val_loss improved from inf to 1.32949, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 80/80 [==============================] - 1159s 14s/step - loss: 1.3783 - accuracy: 1.3783 - matthews_correlation_coefficient: -0.0102 - val_loss: 1.3295 - val_accuracy: 1.3295 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 2/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2861 - accuracy: 1.2861 - matthews_correlation_coefficient: 0.0040
# Epoch 2: val_loss did not improve from 1.32949
# 80/80 [==============================] - 46s 579ms/step - loss: 1.2861 - accuracy: 1.2861 - matthews_correlation_coefficient: 0.0040 - val_loss: 1.3303 - val_accuracy: 1.3303 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 3/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2896 - accuracy: 1.2896 - matthews_correlation_coefficient: 0.0000e+00
# Epoch 3: val_loss improved from 1.32949 to 1.32233, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 45s 557ms/step - loss: 1.2896 - accuracy: 1.2896 - matthews_correlation_coefficient: 0.0000e+00 - val_loss: 1.3223 - val_accuracy: 1.3223 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 4/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2926 - accuracy: 1.2926 - matthews_correlation_coefficient: -0.0067
# Epoch 4: val_loss improved from 1.32233 to 1.32026, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 46s 570ms/step - loss: 1.2926 - accuracy: 1.2926 - matthews_correlation_coefficient: -0.0067 - val_loss: 1.3203 - val_accuracy: 1.3203 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 5/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2753 - accuracy: 1.2753 - matthews_correlation_coefficient: 0.0000e+00
# Epoch 5: val_loss improved from 1.32026 to 1.31879, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 47s 583ms/step - loss: 1.2753 - accuracy: 1.2753 - matthews_correlation_coefficient: 0.0000e+00 - val_loss: 1.3188 - val_accuracy: 1.3188 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 6/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2805 - accuracy: 1.2805 - matthews_correlation_coefficient: 0.0178
# Epoch 6: val_loss did not improve from 1.31879
# 80/80 [==============================] - 45s 556ms/step - loss: 1.2805 - accuracy: 1.2805 - matthews_correlation_coefficient: 0.0178 - val_loss: 1.3192 - val_accuracy: 1.3192 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 7/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2817 - accuracy: 1.2817 - matthews_correlation_coefficient: 0.0000e+00
# Epoch 7: val_loss improved from 1.31879 to 1.31630, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 45s 565ms/step - loss: 1.2817 - accuracy: 1.2817 - matthews_correlation_coefficient: 0.0000e+00 - val_loss: 1.3163 - val_accuracy: 1.3163 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 8/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2774 - accuracy: 1.2774 - matthews_correlation_coefficient: 0.0177
# Epoch 8: val_loss did not improve from 1.31630
# 80/80 [==============================] - 43s 539ms/step - loss: 1.2774 - accuracy: 1.2774 - matthews_correlation_coefficient: 0.0177 - val_loss: 1.3164 - val_accuracy: 1.3164 - val_matthews_correlation_coefficient: 0.0000e+00
# Epoch 9/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2730 - accuracy: 1.2730 - matthews_correlation_coefficient: 0.0104
# Epoch 9: val_loss did not improve from 1.31630
# 80/80 [==============================] - 45s 560ms/step - loss: 1.2730 - accuracy: 1.2730 - matthews_correlation_coefficient: 0.0104 - val_loss: 1.3180 - val_accuracy: 1.3180 - val_matthews_correlation_coefficient: 0.0459
# Epoch 10/10
# 80/80 [==============================] - ETA: 0s - loss: 1.2756 - accuracy: 1.2756 - matthews_correlation_coefficient: -0.0145
# Epoch 10: val_loss improved from 1.31630 to 1.30716, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 47s 591ms/step - loss: 1.2756 - accuracy: 1.2756 - matthews_correlation_coefficient: -0.0145 - val_loss: 1.3072 - val_accuracy: 1.3072 - val_matthews_correlation_coefficient: 0.0000e+00

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

matthews_correlation_coefficient = history.history['matthews_correlation_coefficient']
val_matthews_correlation_coefficient = history.history['val_matthews_correlation_coefficient']

fig, axs = plt.subplots(3, 1, figsize=(5, 15))

plt.subplot(3, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.xlabel('epoch')

plt.subplot(3, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')


plt.subplot(3, 1, 3)
plt.plot(matthews_correlation_coefficient, label='Training MCC')
plt.plot(val_matthews_correlation_coefficient, label='Validation MCC')
plt.legend(loc='upper right')
plt.ylabel('MCC')
plt.ylim([0,1.0])
plt.title('Training and Validation MCC')
plt.xlabel('epoch')
plt.show()

# %%
# Loss
min_loss_index = np.argmin(history.history['loss'])
min_loss_value = round(history.history['loss'][min_loss_index], 4)
print(f'The epoch with the lowest loss is: {min_loss_index + 1} (Loss: {min_loss_value})')

# Validation Loss
min_val_loss_index = np.argmin(history.history['val_loss'])
min_val_loss_value = round(history.history['val_loss'][min_val_loss_index], 4)
print(f'The epoch with the lowest val_loss is: {min_val_loss_index + 1} (Val Loss: {min_val_loss_value})')

# Accuracy
max_accuracy_index = np.argmax(history.history['accuracy'])
max_accuracy_value = round(history.history['accuracy'][max_accuracy_index], 4)
print(f'The epoch with the highest accuracy is: {max_accuracy_index + 1} (Accuracy: {max_accuracy_value})')

# Validation Accuracy
max_val_acc_index = np.argmax(history.history['val_accuracy'])
max_val_acc_value = round(history.history['val_accuracy'][max_val_acc_index], 4)
print(f'The epoch with the highest validation accuracy is: {max_val_acc_index + 1} (Val Accuracy: {max_val_acc_value})')

# Matthews Correlation Coefficient (MCC)
max_mcc_index = np.argmax(history.history['matthews_correlation_coefficient'])
max_mcc_value = round(history.history['matthews_correlation_coefficient'][max_mcc_index], 4)
print(f'The epoch with the highest MCC is: {max_mcc_index + 1} (MCC: {max_mcc_value})')

# Validation MCC
max_val_mcc_index = np.argmax(history.history['val_matthews_correlation_coefficient'])
max_val_mcc_value = round(history.history['val_matthews_correlation_coefficient'][max_val_mcc_index], 4)
print(f'The epoch with the highest validation MCC is: {max_val_mcc_index + 1} (Val MCC: {max_val_mcc_value})')

best_epoch_model = max_val_mcc_index + 1
# Out:
# The epoch with the lowest loss is: 9 (Loss: 1.273)
# The epoch with the lowest val_loss is: 10 (Val Loss: 1.3072)
# The epoch with the highest accuracy is: 1 (Accuracy: 1.3783)
# The epoch with the highest validation accuracy is: 2 (Val Accuracy: 1.3303)
# The epoch with the highest MCC is: 6 (MCC: 0.0178)
# The epoch with the highest validation MCC is: 9 (Val MCC: 0.0459)

# %%
base_model.trainable = True

# %%
# Total layers in the base model
print("Number of layers in the base model: ", len(base_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False
# Out:
# Number of layers in the base model:  409

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate/10),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
              metrics=[tf.keras.metrics.CategoricalCrossentropy(name='accuracy'),mcc_metric])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetv2-b3 (Functio  (None, 7, 7, 1536)        12930622
#  nal)
#
#  global_average_pooling2d (  (None, 1536)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1536)              0
#
#  dense (Dense)               (None, 5)                 7685
#
# =================================================================
# Total params: 12938307 (49.36 MB)
# Trainable params: 11992821 (45.75 MB)
# Non-trainable params: 945486 (3.61 MB)
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 272

# %%
fine_tune_epochs = 45
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_generator, steps_per_epoch = train_generator.n // 32, epochs = total_epochs, initial_epoch=history.epoch[-1], validation_data= validation_generator, validation_steps= validation_generator.n // 32, callbacks=[checkpointer , earlystopping])
# Out:
# Epoch 10/55
# 80/80 [==============================] - ETA: 0s - loss: 1.2677 - accuracy: 1.2677 - matthews_correlation_coefficient: 0.0570
# Epoch 10: val_loss improved from 1.30716 to 1.27702, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 103s 664ms/step - loss: 1.2677 - accuracy: 1.2677 - matthews_correlation_coefficient: 0.0570 - val_loss: 1.2770 - val_accuracy: 1.2770 - val_matthews_correlation_coefficient: 0.1142
# Epoch 11/55
# 80/80 [==============================] - ETA: 0s - loss: 1.2230 - accuracy: 1.2230 - matthews_correlation_coefficient: 0.1514
# Epoch 11: val_loss improved from 1.27702 to 1.21019, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 54s 669ms/step - loss: 1.2230 - accuracy: 1.2230 - matthews_correlation_coefficient: 0.1514 - val_loss: 1.2102 - val_accuracy: 1.2102 - val_matthews_correlation_coefficient: 0.2882
# Epoch 12/55
# 80/80 [==============================] - ETA: 0s - loss: 1.1970 - accuracy: 1.1970 - matthews_correlation_coefficient: 0.2073
# Epoch 12: val_loss improved from 1.21019 to 1.19122, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 51s 635ms/step - loss: 1.1970 - accuracy: 1.1970 - matthews_correlation_coefficient: 0.2073 - val_loss: 1.1912 - val_accuracy: 1.1912 - val_matthews_correlation_coefficient: 0.3268
# Epoch 13/55
# 80/80 [==============================] - ETA: 0s - loss: 1.1583 - accuracy: 1.1583 - matthews_correlation_coefficient: 0.2896
# Epoch 13: val_loss did not improve from 1.19122
# 80/80 [==============================] - 49s 615ms/step - loss: 1.1583 - accuracy: 1.1583 - matthews_correlation_coefficient: 0.2896 - val_loss: 1.2484 - val_accuracy: 1.2484 - val_matthews_correlation_coefficient: 0.3091
# Epoch 14/55
# 80/80 [==============================] - ETA: 0s - loss: 1.1462 - accuracy: 1.1462 - matthews_correlation_coefficient: 0.2984
# Epoch 14: val_loss did not improve from 1.19122
# 80/80 [==============================] - 47s 586ms/step - loss: 1.1462 - accuracy: 1.1462 - matthews_correlation_coefficient: 0.2984 - val_loss: 1.1933 - val_accuracy: 1.1933 - val_matthews_correlation_coefficient: 0.3473
# Epoch 15/55
# 80/80 [==============================] - ETA: 0s - loss: 1.1126 - accuracy: 1.1126 - matthews_correlation_coefficient: 0.3297
# Epoch 15: val_loss improved from 1.19122 to 1.10816, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 51s 636ms/step - loss: 1.1126 - accuracy: 1.1126 - matthews_correlation_coefficient: 0.3297 - val_loss: 1.1082 - val_accuracy: 1.1082 - val_matthews_correlation_coefficient: 0.3693
# Epoch 16/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0891 - accuracy: 1.0891 - matthews_correlation_coefficient: 0.3590
# Epoch 16: val_loss improved from 1.10816 to 1.04377, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 54s 666ms/step - loss: 1.0891 - accuracy: 1.0891 - matthews_correlation_coefficient: 0.3590 - val_loss: 1.0438 - val_accuracy: 1.0438 - val_matthews_correlation_coefficient: 0.4223
# Epoch 17/55
# 80/80 [==============================] - ETA: 0s - loss: 1.1497 - accuracy: 1.1497 - matthews_correlation_coefficient: 0.2791
# Epoch 17: val_loss did not improve from 1.04377
# 80/80 [==============================] - 49s 614ms/step - loss: 1.1497 - accuracy: 1.1497 - matthews_correlation_coefficient: 0.2791 - val_loss: 1.0874 - val_accuracy: 1.0874 - val_matthews_correlation_coefficient: 0.4278
# Epoch 18/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0389 - accuracy: 1.0389 - matthews_correlation_coefficient: 0.3854
# Epoch 18: val_loss improved from 1.04377 to 0.99359, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 52s 655ms/step - loss: 1.0389 - accuracy: 1.0389 - matthews_correlation_coefficient: 0.3854 - val_loss: 0.9936 - val_accuracy: 0.9936 - val_matthews_correlation_coefficient: 0.4330
# Epoch 19/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0422 - accuracy: 1.0422 - matthews_correlation_coefficient: 0.3894
# Epoch 19: val_loss did not improve from 0.99359
# 80/80 [==============================] - 49s 609ms/step - loss: 1.0422 - accuracy: 1.0422 - matthews_correlation_coefficient: 0.3894 - val_loss: 1.0964 - val_accuracy: 1.0964 - val_matthews_correlation_coefficient: 0.4080
# Epoch 20/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0178 - accuracy: 1.0178 - matthews_correlation_coefficient: 0.4162
# Epoch 20: val_loss improved from 0.99359 to 0.97093, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 53s 663ms/step - loss: 1.0178 - accuracy: 1.0178 - matthews_correlation_coefficient: 0.4162 - val_loss: 0.9709 - val_accuracy: 0.9709 - val_matthews_correlation_coefficient: 0.4513
# Epoch 21/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0141 - accuracy: 1.0141 - matthews_correlation_coefficient: 0.4060
# Epoch 21: val_loss did not improve from 0.97093
# 80/80 [==============================] - 49s 613ms/step - loss: 1.0141 - accuracy: 1.0141 - matthews_correlation_coefficient: 0.4060 - val_loss: 0.9870 - val_accuracy: 0.9870 - val_matthews_correlation_coefficient: 0.4550
# Epoch 22/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0025 - accuracy: 1.0025 - matthews_correlation_coefficient: 0.4195
# Epoch 22: val_loss did not improve from 0.97093
# 80/80 [==============================] - 48s 599ms/step - loss: 1.0025 - accuracy: 1.0025 - matthews_correlation_coefficient: 0.4195 - val_loss: 1.0426 - val_accuracy: 1.0426 - val_matthews_correlation_coefficient: 0.4331
# Epoch 23/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9999 - accuracy: 0.9999 - matthews_correlation_coefficient: 0.4315
# Epoch 23: val_loss improved from 0.97093 to 0.95947, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 53s 659ms/step - loss: 0.9999 - accuracy: 0.9999 - matthews_correlation_coefficient: 0.4315 - val_loss: 0.9595 - val_accuracy: 0.9595 - val_matthews_correlation_coefficient: 0.4544
# Epoch 24/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9728 - accuracy: 0.9728 - matthews_correlation_coefficient: 0.4403
# Epoch 24: val_loss improved from 0.95947 to 0.93520, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 52s 652ms/step - loss: 0.9728 - accuracy: 0.9728 - matthews_correlation_coefficient: 0.4403 - val_loss: 0.9352 - val_accuracy: 0.9352 - val_matthews_correlation_coefficient: 0.4816
# Epoch 25/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0057 - accuracy: 1.0057 - matthews_correlation_coefficient: 0.4109
# Epoch 25: val_loss did not improve from 0.93520
# 80/80 [==============================] - 49s 602ms/step - loss: 1.0057 - accuracy: 1.0057 - matthews_correlation_coefficient: 0.4109 - val_loss: 0.9552 - val_accuracy: 0.9552 - val_matthews_correlation_coefficient: 0.4599
# Epoch 26/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9896 - accuracy: 0.9896 - matthews_correlation_coefficient: 0.4402
# Epoch 26: val_loss did not improve from 0.93520
# 80/80 [==============================] - 49s 605ms/step - loss: 0.9896 - accuracy: 0.9896 - matthews_correlation_coefficient: 0.4402 - val_loss: 0.9486 - val_accuracy: 0.9486 - val_matthews_correlation_coefficient: 0.4509
# Epoch 27/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9782 - accuracy: 0.9782 - matthews_correlation_coefficient: 0.4325
# Epoch 27: val_loss did not improve from 0.93520
# 80/80 [==============================] - 50s 621ms/step - loss: 0.9782 - accuracy: 0.9782 - matthews_correlation_coefficient: 0.4325 - val_loss: 0.9369 - val_accuracy: 0.9369 - val_matthews_correlation_coefficient: 0.4678
# Epoch 28/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9663 - accuracy: 0.9663 - matthews_correlation_coefficient: 0.4416
# Epoch 28: val_loss improved from 0.93520 to 0.93234, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 52s 651ms/step - loss: 0.9663 - accuracy: 0.9663 - matthews_correlation_coefficient: 0.4416 - val_loss: 0.9323 - val_accuracy: 0.9323 - val_matthews_correlation_coefficient: 0.4676
# Epoch 29/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9612 - accuracy: 0.9612 - matthews_correlation_coefficient: 0.4533
# Epoch 29: val_loss improved from 0.93234 to 0.90931, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 52s 653ms/step - loss: 0.9612 - accuracy: 0.9612 - matthews_correlation_coefficient: 0.4533 - val_loss: 0.9093 - val_accuracy: 0.9093 - val_matthews_correlation_coefficient: 0.4774
# Epoch 30/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9818 - accuracy: 0.9818 - matthews_correlation_coefficient: 0.4324
# Epoch 30: val_loss did not improve from 0.90931
# 80/80 [==============================] - 49s 611ms/step - loss: 0.9818 - accuracy: 0.9818 - matthews_correlation_coefficient: 0.4324 - val_loss: 0.9693 - val_accuracy: 0.9693 - val_matthews_correlation_coefficient: 0.4755
# Epoch 31/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9635 - accuracy: 0.9635 - matthews_correlation_coefficient: 0.4436
# Epoch 31: val_loss did not improve from 0.90931
# 80/80 [==============================] - 49s 609ms/step - loss: 0.9635 - accuracy: 0.9635 - matthews_correlation_coefficient: 0.4436 - val_loss: 0.9233 - val_accuracy: 0.9233 - val_matthews_correlation_coefficient: 0.4675
# Epoch 32/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9450 - accuracy: 0.9450 - matthews_correlation_coefficient: 0.4603
# Epoch 32: val_loss did not improve from 0.90931
# 80/80 [==============================] - 48s 603ms/step - loss: 0.9450 - accuracy: 0.9450 - matthews_correlation_coefficient: 0.4603 - val_loss: 0.9535 - val_accuracy: 0.9535 - val_matthews_correlation_coefficient: 0.4838
# Epoch 33/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9665 - accuracy: 0.9665 - matthews_correlation_coefficient: 0.4424
# Epoch 33: val_loss did not improve from 0.90931
# 80/80 [==============================] - 49s 615ms/step - loss: 0.9665 - accuracy: 0.9665 - matthews_correlation_coefficient: 0.4424 - val_loss: 0.9186 - val_accuracy: 0.9186 - val_matthews_correlation_coefficient: 0.4703
# Epoch 34/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9299 - accuracy: 0.9299 - matthews_correlation_coefficient: 0.4715
# Epoch 34: val_loss did not improve from 0.90931
# 80/80 [==============================] - 49s 615ms/step - loss: 0.9299 - accuracy: 0.9299 - matthews_correlation_coefficient: 0.4715 - val_loss: 0.9377 - val_accuracy: 0.9377 - val_matthews_correlation_coefficient: 0.4875
# Epoch 35/55
# 80/80 [==============================] - ETA: 0s - loss: 1.0144 - accuracy: 1.0144 - matthews_correlation_coefficient: 0.4140
# Epoch 35: val_loss did not improve from 0.90931
# 80/80 [==============================] - 49s 612ms/step - loss: 1.0144 - accuracy: 1.0144 - matthews_correlation_coefficient: 0.4140 - val_loss: 0.9367 - val_accuracy: 0.9367 - val_matthews_correlation_coefficient: 0.4781
# Epoch 36/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9312 - accuracy: 0.9312 - matthews_correlation_coefficient: 0.4710
# Epoch 36: val_loss did not improve from 0.90931
# 80/80 [==============================] - 49s 612ms/step - loss: 0.9312 - accuracy: 0.9312 - matthews_correlation_coefficient: 0.4710 - val_loss: 0.9159 - val_accuracy: 0.9159 - val_matthews_correlation_coefficient: 0.4673
# Epoch 37/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9384 - accuracy: 0.9384 - matthews_correlation_coefficient: 0.4717
# Epoch 37: val_loss did not improve from 0.90931
# 80/80 [==============================] - 49s 611ms/step - loss: 0.9384 - accuracy: 0.9384 - matthews_correlation_coefficient: 0.4717 - val_loss: 0.9260 - val_accuracy: 0.9260 - val_matthews_correlation_coefficient: 0.4669
# Epoch 38/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9364 - accuracy: 0.9364 - matthews_correlation_coefficient: 0.4740
# Epoch 38: val_loss did not improve from 0.90931
# 80/80 [==============================] - 49s 612ms/step - loss: 0.9364 - accuracy: 0.9364 - matthews_correlation_coefficient: 0.4740 - val_loss: 0.9135 - val_accuracy: 0.9135 - val_matthews_correlation_coefficient: 0.4705
# Epoch 39/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9220 - accuracy: 0.9220 - matthews_correlation_coefficient: 0.4663
# Epoch 39: val_loss did not improve from 0.90931
# 80/80 [==============================] - 49s 611ms/step - loss: 0.9220 - accuracy: 0.9220 - matthews_correlation_coefficient: 0.4663 - val_loss: 0.9416 - val_accuracy: 0.9416 - val_matthews_correlation_coefficient: 0.4830
# Epoch 40/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9219 - accuracy: 0.9219 - matthews_correlation_coefficient: 0.4714
# Epoch 40: val_loss improved from 0.90931 to 0.90607, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 53s 666ms/step - loss: 0.9219 - accuracy: 0.9219 - matthews_correlation_coefficient: 0.4714 - val_loss: 0.9061 - val_accuracy: 0.9061 - val_matthews_correlation_coefficient: 0.4622
# Epoch 41/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9294 - accuracy: 0.9294 - matthews_correlation_coefficient: 0.4595
# Epoch 41: val_loss did not improve from 0.90607
# 80/80 [==============================] - 50s 623ms/step - loss: 0.9294 - accuracy: 0.9294 - matthews_correlation_coefficient: 0.4595 - val_loss: 0.9399 - val_accuracy: 0.9399 - val_matthews_correlation_coefficient: 0.4571
# Epoch 42/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9339 - accuracy: 0.9339 - matthews_correlation_coefficient: 0.4734
# Epoch 42: val_loss did not improve from 0.90607
# 80/80 [==============================] - 49s 617ms/step - loss: 0.9339 - accuracy: 0.9339 - matthews_correlation_coefficient: 0.4734 - val_loss: 0.9161 - val_accuracy: 0.9161 - val_matthews_correlation_coefficient: 0.4734
# Epoch 43/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9200 - accuracy: 0.9200 - matthews_correlation_coefficient: 0.4694
# Epoch 43: val_loss did not improve from 0.90607
# 80/80 [==============================] - 48s 602ms/step - loss: 0.9200 - accuracy: 0.9200 - matthews_correlation_coefficient: 0.4694 - val_loss: 0.9821 - val_accuracy: 0.9821 - val_matthews_correlation_coefficient: 0.4521
# Epoch 44/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9556 - accuracy: 0.9556 - matthews_correlation_coefficient: 0.4545
# Epoch 44: val_loss did not improve from 0.90607
# 80/80 [==============================] - 49s 614ms/step - loss: 0.9556 - accuracy: 0.9556 - matthews_correlation_coefficient: 0.4545 - val_loss: 0.9516 - val_accuracy: 0.9516 - val_matthews_correlation_coefficient: 0.4843
# Epoch 45/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9046 - accuracy: 0.9046 - matthews_correlation_coefficient: 0.4808
# Epoch 45: val_loss improved from 0.90607 to 0.89694, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 54s 679ms/step - loss: 0.9046 - accuracy: 0.9046 - matthews_correlation_coefficient: 0.4808 - val_loss: 0.8969 - val_accuracy: 0.8969 - val_matthews_correlation_coefficient: 0.4682
# Epoch 46/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9234 - accuracy: 0.9234 - matthews_correlation_coefficient: 0.4747
# Epoch 46: val_loss did not improve from 0.89694
# 80/80 [==============================] - 51s 634ms/step - loss: 0.9234 - accuracy: 0.9234 - matthews_correlation_coefficient: 0.4747 - val_loss: 0.9081 - val_accuracy: 0.9081 - val_matthews_correlation_coefficient: 0.4675
# Epoch 47/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9192 - accuracy: 0.9192 - matthews_correlation_coefficient: 0.4735
# Epoch 47: val_loss did not improve from 0.89694
# 80/80 [==============================] - 49s 616ms/step - loss: 0.9192 - accuracy: 0.9192 - matthews_correlation_coefficient: 0.4735 - val_loss: 0.9141 - val_accuracy: 0.9141 - val_matthews_correlation_coefficient: 0.4677
# Epoch 48/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9096 - accuracy: 0.9096 - matthews_correlation_coefficient: 0.4686
# Epoch 48: val_loss did not improve from 0.89694
# 80/80 [==============================] - 49s 612ms/step - loss: 0.9096 - accuracy: 0.9096 - matthews_correlation_coefficient: 0.4686 - val_loss: 0.9100 - val_accuracy: 0.9100 - val_matthews_correlation_coefficient: 0.4740
# Epoch 49/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9109 - accuracy: 0.9109 - matthews_correlation_coefficient: 0.4755
# Epoch 49: val_loss did not improve from 0.89694
# 80/80 [==============================] - 50s 621ms/step - loss: 0.9109 - accuracy: 0.9109 - matthews_correlation_coefficient: 0.4755 - val_loss: 0.9176 - val_accuracy: 0.9176 - val_matthews_correlation_coefficient: 0.4598
# Epoch 50/55
# 80/80 [==============================] - ETA: 0s - loss: 0.8949 - accuracy: 0.8949 - matthews_correlation_coefficient: 0.4860
# Epoch 50: val_loss did not improve from 0.89694
# 80/80 [==============================] - 49s 613ms/step - loss: 0.8949 - accuracy: 0.8949 - matthews_correlation_coefficient: 0.4860 - val_loss: 0.9412 - val_accuracy: 0.9412 - val_matthews_correlation_coefficient: 0.4645
# Epoch 51/55
# 80/80 [==============================] - ETA: 0s - loss: 0.8996 - accuracy: 0.8996 - matthews_correlation_coefficient: 0.4708
# Epoch 51: val_loss did not improve from 0.89694
# 80/80 [==============================] - 49s 613ms/step - loss: 0.8996 - accuracy: 0.8996 - matthews_correlation_coefficient: 0.4708 - val_loss: 0.9053 - val_accuracy: 0.9053 - val_matthews_correlation_coefficient: 0.4563
# Epoch 52/55
# 80/80 [==============================] - ETA: 0s - loss: 0.8962 - accuracy: 0.8962 - matthews_correlation_coefficient: 0.4957
# Epoch 52: val_loss did not improve from 0.89694
# 80/80 [==============================] - 50s 622ms/step - loss: 0.8962 - accuracy: 0.8962 - matthews_correlation_coefficient: 0.4957 - val_loss: 0.9687 - val_accuracy: 0.9687 - val_matthews_correlation_coefficient: 0.4388
# Epoch 53/55
# 80/80 [==============================] - ETA: 0s - loss: 0.8959 - accuracy: 0.8959 - matthews_correlation_coefficient: 0.4993
# Epoch 53: val_loss improved from 0.89694 to 0.89670, saving model to /content/drive/MyDrive/drweights/EffNetweightsd5b.hdf5
# 80/80 [==============================] - 57s 711ms/step - loss: 0.8959 - accuracy: 0.8959 - matthews_correlation_coefficient: 0.4993 - val_loss: 0.8967 - val_accuracy: 0.8967 - val_matthews_correlation_coefficient: 0.4789
# Epoch 54/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9276 - accuracy: 0.9276 - matthews_correlation_coefficient: 0.4569
# Epoch 54: val_loss did not improve from 0.89670
# 80/80 [==============================] - 50s 618ms/step - loss: 0.9276 - accuracy: 0.9276 - matthews_correlation_coefficient: 0.4569 - val_loss: 0.9073 - val_accuracy: 0.9073 - val_matthews_correlation_coefficient: 0.4686
# Epoch 55/55
# 80/80 [==============================] - ETA: 0s - loss: 0.9012 - accuracy: 0.9012 - matthews_correlation_coefficient: 0.4889
# Epoch 55: val_loss did not improve from 0.89670
# 80/80 [==============================] - 49s 617ms/step - loss: 0.9012 - accuracy: 0.9012 - matthews_correlation_coefficient: 0.4889 - val_loss: 0.8984 - val_accuracy: 0.8984 - val_matthews_correlation_coefficient: 0.4714

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

matthews_correlation_coefficient += history_fine.history['matthews_correlation_coefficient']
val_matthews_correlation_coefficient += history_fine.history['val_matthews_correlation_coefficient']

# %%
fig, axs = plt.subplots(3, 1, figsize=(5, 15))

plt.subplot(3, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.8, 1])
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('epoch')

plt.subplot(3, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')

plt.subplot(3, 1, 3)
plt.plot(matthews_correlation_coefficient, label='Training MCC')
plt.plot(val_matthews_correlation_coefficient, label='Validation MCC')
plt.ylim([0, 1.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation MCC')
plt.xlabel('epoch')

plt.show()

# %%
# Loss
min_loss_index = np.argmin(history_fine.history['loss'])
min_loss_value = round(history_fine.history['loss'][min_loss_index], 4)
print(f'The epoch with the lowest loss is: {min_loss_index + 1} (Loss: {min_loss_value})')

# Validation Loss
min_val_loss_index = np.argmin(history_fine.history['val_loss'])
min_val_loss_value = round(history_fine.history['val_loss'][min_val_loss_index], 4)
print(f'The epoch with the lowest val_loss is: {min_val_loss_index + 1} (Val Loss: {min_val_loss_value})')

# Accuracy
max_accuracy_index = np.argmax(history_fine.history['accuracy'])
max_accuracy_value = round(history_fine.history['accuracy'][max_accuracy_index], 4)
print(f'The epoch with the highest accuracy is: {max_accuracy_index + 1} (Accuracy: {max_accuracy_value})')

# Validation Accuracy
max_val_acc_index = np.argmax(history_fine.history['val_accuracy'])
max_val_acc_value = round(history_fine.history['val_accuracy'][max_val_acc_index], 4)
print(f'The epoch with the highest validation accuracy is: {max_val_acc_index + 1} (Val Accuracy: {max_val_acc_value})')

# Matthews Correlation Coefficient (MCC)
max_mcc_index = np.argmax(history_fine.history['matthews_correlation_coefficient'])
max_mcc_value = round(history_fine.history['matthews_correlation_coefficient'][max_mcc_index], 4)
print(f'The epoch with the highest MCC is: {max_mcc_index + 1} (MCC: {max_mcc_value})')

# Validation MCC
max_val_mcc_index = np.argmax(history_fine.history['val_matthews_correlation_coefficient'])
max_val_mcc_value = round(history_fine.history['val_matthews_correlation_coefficient'][max_val_mcc_index], 4)
print(f'The epoch with the highest validation MCC is: {max_val_mcc_index + 1} (Val MCC: {max_val_mcc_value})')

best_epoch_model = max_val_mcc_index + 1
# Out:
# The epoch with the lowest loss is: 41 (Loss: 0.8949)
# The epoch with the lowest val_loss is: 44 (Val Loss: 0.8967)
# The epoch with the highest accuracy is: 1 (Accuracy: 1.2677)
# The epoch with the highest validation accuracy is: 1 (Val Accuracy: 1.277)
# The epoch with the highest MCC is: 44 (MCC: 0.4993)
# The epoch with the highest validation MCC is: 25 (Val MCC: 0.4875)

# %%
#model.load_weights("/content/drive/MyDrive/drweights/EffNetweights720.hdf5")

# %% [markdown]
# #Testing

# %%
loss, accuracy, matthews_correlation_coefficient = model.evaluate(test_generator)
print('Test accuracy :', accuracy, 'Test MCC :', matthews_correlation_coefficient)
# Out:
# 18/18 [==============================] - 175s 10s/step - loss: 0.8192 - accuracy: 0.8192 - matthews_correlation_coefficient: 0.5056
# Test accuracy : 0.8191895484924316 Test MCC : 0.5055538415908813

# %%
# Predicting on the entire test set
predictions = model.predict(test_generator)

# Convert predictions from probability to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming your test_generator.classes is already a 1D array of class labels
true_labels = test_generator.classes

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Generate and print classification report
report = classification_report(true_labels, predicted_labels)
print("\nClassification Report:")
print(report)
# Out:
# 18/18 [==============================] - 5s 134ms/step
# Confusion Matrix:
# [[  0  24  31   0   0]
#  [  0  70  94   0   0]
#  [  0 119 140   0   0]
#  [  0  16  29   0   0]
#  [  0  13  14   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        55
#            1       0.29      0.43      0.34       164
#            2       0.45      0.54      0.49       259
#            3       0.00      0.00      0.00        45
#            4       0.00      0.00      0.00        27
#
#     accuracy                           0.38       550
#    macro avg       0.15      0.19      0.17       550
# weighted avg       0.30      0.38      0.34       550
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
class_names = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative DR']

FP = conf_matrix.sum(axis=0) - np.diag(conf_matrix)
FN = conf_matrix.sum(axis=1) - np.diag(conf_matrix)
TP = np.diag(conf_matrix)
TN = conf_matrix.sum() - (FP + FN + TP)
FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)


# Calculate the metrics with conditions to handle division by zero
TPR = np.divide(TP, TP + FN, out=np.zeros_like(TP), where=(TP+FN)!=0)
TNR = np.divide(TN, TN + FP, out=np.zeros_like(TN), where=(TN+FP)!=0)
PPV = np.divide(TP, TP + FP, out=np.zeros_like(TP), where=(TP+FP)!=0)
NPV = np.divide(TN, TN + FN, out=np.zeros_like(TN), where=(TN+FN)!=0)
FPR = np.divide(FP, FP + TN, out=np.zeros_like(FP), where=(FP+TN)!=0)
FNR = np.divide(FN, TP + FN, out=np.zeros_like(FN), where=(TP+FN)!=0)
FDR = np.divide(FP, TP + FP, out=np.zeros_like(FP), where=(TP+FP)!=0)
ACC = np.divide(TP + TN, TP + FP + FN + TN, out=np.zeros_like(TP+TN), where=(TP+FP+FN+TN)!=0)

# Print metrics for each class
for i in range(len(class_names)):
    print(f"Class - {class_names[i]}")
    print(f"  Sensitivity: {TPR[i]}")
    print(f"  Specificity: {TNR[i]}")
    print(f"  Precision: {PPV[i]}")
    print(f"  Negative Predictive Value: {NPV[i]}")
    print(f"  False Positive Rate: {FPR[i]}")
    print(f"  False Negative Rate: {FNR[i]}")
    print(f"  False Discovery Rate: {FDR[i]}")
    print(f"  Overall Accuracy: {ACC[i]}\n")
# Out:
# Class - No DR
#   Sensitivity: 0.0
#   Specificity: 1.0
#   Precision: 0.0
#   Negative Predictive Value: 0.9
#   False Positive Rate: 0.0
#   False Negative Rate: 1.0
#   False Discovery Rate: 0.0
#   Overall Accuracy: 0.9
#
# Class - Mild
#   Sensitivity: 0.4268292682926829
#   Specificity: 0.5544041450777202
#   Precision: 0.2892561983471074
#   Negative Predictive Value: 0.6948051948051948
#   False Positive Rate: 0.44559585492227977
#   False Negative Rate: 0.573170731707317
#   False Discovery Rate: 0.7107438016528925
#   Overall Accuracy: 0.5163636363636364
#
# Class - Moderate
#   Sensitivity: 0.5405405405405406
#   Specificity: 0.422680412371134
#   Precision: 0.45454545454545453
#   Negative Predictive Value: 0.5082644628099173
#   False Positive Rate: 0.5773195876288659
#   False Negative Rate: 0.4594594594594595
#   False Discovery Rate: 0.5454545454545454
#   Overall Accuracy: 0.4781818181818182
#
# Class - Severe
#   Sensitivity: 0.0
#   Specificity: 1.0
#   Precision: 0.0
#   Negative Predictive Value: 0.9181818181818182
#   False Positive Rate: 0.0
#   False Negative Rate: 1.0
#   False Discovery Rate: 0.0
#   Overall Accuracy: 0.9181818181818182
#
# Class - Proliferative DR
#   Sensitivity: 0.0
#   Specificity: 1.0
#   Precision: 0.0
#   Negative Predictive Value: 0.9509090909090909
#   False Positive Rate: 0.0
#   False Negative Rate: 1.0
#   False Discovery Rate: 0.0
#   Overall Accuracy: 0.9509090909090909

# %%
# Metrics to plot
metrics = [TPR, TNR, PPV, NPV, FPR, FNR, FDR, ACC]
metric_names = ['Sensitivity', 'Specificity', 'Precision', 'NPV', 'FPR', 'FNR', 'FDR', 'Accuracy']

# Plotting
fig, axes = plt.subplots(4, 2, figsize=(10, 15))  # Adjust the size as needed
axes = axes.ravel()

for i, ax in enumerate(axes):
    ax.bar(class_names, metrics[i], color='skyblue')
    ax.set_title(metric_names[i])
    ax.set_ylim(0, 1)  # Assuming metrics are between 0 and 1
    ax.set_ylabel('Value')
    ax.set_xticklabels(class_names, rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-46-86800b8bc2b8>:14: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
class_labels = class_names

plt.figure(figsize=(10, 7))

# Create a heatmap
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# # Evaluate on secondary DR Detection eyePACS test dataset

# %%
eyepacs_df = pd.read_csv('/content/drive/MyDrive/minitest.csv')
eyepacs_df.rename(columns={'image': 'Image', 'level': 'Labels'}, inplace=True)
eyepacs_df['Labels'].replace({0: 'No_DR', 1: 'Mild', 2: 'Moderate', 3: 'Severe', 4: 'Proliferative_DR'}, inplace=True)
eyepacs_df['Image'] = eyepacs_df['Image'] + '.jpeg'
eyepacs_df.head()
# Out:
#               Image Labels
# 0  17123_right.jpeg  No_DR
# 1  12616_right.jpeg  No_DR
# 2    6541_left.jpeg  No_DR
# 3  14418_right.jpeg  No_DR
# 4   39598_left.jpeg  No_DR

# %%
# eyepacs generator

eyepacs_datagen = ImageDataGenerator(rescale = 1./255)

base_path = '/content/drive/My Drive/eyepacs'  # Your base path

eyepacs_generator = eyepacs_datagen.flow_from_dataframe(
    eyepacs_df,
    directory=base_path,  # Updated directory path
    x_col="Image",
    y_col="Labels",
    target_size=(224, 224),
    color_mode="rgb",
    class_mode="categorical",
    batch_size=32)
# Out:
# Found 1001 validated image filenames belonging to 5 classes.

# %%
loss, accuracy, matthews_correlation_coefficient = model.evaluate(eyepacs_generator)
print('Test accuracy :', accuracy, 'Test MCC :', matthews_correlation_coefficient)
# Out:
# 32/32 [==============================] - 283s 9s/step - loss: 1.0401 - accuracy: 1.0401 - matthews_correlation_coefficient: 0.0283
# Test accuracy : 1.0401314496994019 Test MCC : 0.028272967785596848

# %%
# Predicting on the entire test set
predictions = model.predict(eyepacs_generator)

# Convert predictions from probability to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming your test_generator.classes is already a 1D array of class labels
true_labels = eyepacs_generator.classes

# Generate the confusion matrix
epconf_matrix = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(epconf_matrix)

# Generate and print classification report
report = classification_report(true_labels, predicted_labels)
print("\nClassification Report:")
print(report)
# Out:
# 32/32 [==============================] - 3s 93ms/step
# Confusion Matrix:
# [[  0   5  65   0   0]
#  [  0   6 145   0   0]
#  [  0  86 649   0   0]
#  [  0   1  19   0   0]
#  [  0   3  22   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        70
#            1       0.06      0.04      0.05       151
#            2       0.72      0.88      0.79       735
#            3       0.00      0.00      0.00        20
#            4       0.00      0.00      0.00        25
#
#     accuracy                           0.65      1001
#    macro avg       0.16      0.18      0.17      1001
# weighted avg       0.54      0.65      0.59      1001
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
class_names = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative DR']

FP = epconf_matrix.sum(axis=0) - np.diag(epconf_matrix)
FN = epconf_matrix.sum(axis=1) - np.diag(epconf_matrix)
TP = np.diag(epconf_matrix)
TN = epconf_matrix.sum() - (FP + FN + TP)
FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)


# Calculate the metrics with conditions to handle division by zero
TPR = np.divide(TP, TP + FN, out=np.zeros_like(TP), where=(TP+FN)!=0)
TNR = np.divide(TN, TN + FP, out=np.zeros_like(TN), where=(TN+FP)!=0)
PPV = np.divide(TP, TP + FP, out=np.zeros_like(TP), where=(TP+FP)!=0)
NPV = np.divide(TN, TN + FN, out=np.zeros_like(TN), where=(TN+FN)!=0)
FPR = np.divide(FP, FP + TN, out=np.zeros_like(FP), where=(FP+TN)!=0)
FNR = np.divide(FN, TP + FN, out=np.zeros_like(FN), where=(TP+FN)!=0)
FDR = np.divide(FP, TP + FP, out=np.zeros_like(FP), where=(TP+FP)!=0)
ACC = np.divide(TP + TN, TP + FP + FN + TN, out=np.zeros_like(TP+TN), where=(TP+FP+FN+TN)!=0)

# Print metrics for each class
for i in range(len(class_names)):
    print(f"Class - {class_names[i]}")
    print(f"  Sensitivity: {TPR[i]}")
    print(f"  Specificity: {TNR[i]}")
    print(f"  Precision: {PPV[i]}")
    print(f"  Negative Predictive Value: {NPV[i]}")
    print(f"  False Positive Rate: {FPR[i]}")
    print(f"  False Negative Rate: {FNR[i]}")
    print(f"  False Discovery Rate: {FDR[i]}")
    print(f"  Overall Accuracy: {ACC[i]}\n")
# Out:
# Class - No DR
#   Sensitivity: 0.0
#   Specificity: 1.0
#   Precision: 0.0
#   Negative Predictive Value: 0.9300699300699301
#   False Positive Rate: 0.0
#   False Negative Rate: 1.0
#   False Discovery Rate: 0.0
#   Overall Accuracy: 0.9300699300699301
#
# Class - Mild
#   Sensitivity: 0.039735099337748346
#   Specificity: 0.888235294117647
#   Precision: 0.0594059405940594
#   Negative Predictive Value: 0.8388888888888889
#   False Positive Rate: 0.11176470588235295
#   False Negative Rate: 0.9602649006622517
#   False Discovery Rate: 0.9405940594059405
#   Overall Accuracy: 0.7602397602397603
#
# Class - Moderate
#   Sensitivity: 0.8829931972789116
#   Specificity: 0.05639097744360902
#   Precision: 0.7211111111111111
#   Negative Predictive Value: 0.1485148514851485
#   False Positive Rate: 0.943609022556391
#   False Negative Rate: 0.11700680272108843
#   False Discovery Rate: 0.2788888888888889
#   Overall Accuracy: 0.6633366633366633
#
# Class - Severe
#   Sensitivity: 0.0
#   Specificity: 1.0
#   Precision: 0.0
#   Negative Predictive Value: 0.98001998001998
#   False Positive Rate: 0.0
#   False Negative Rate: 1.0
#   False Discovery Rate: 0.0
#   Overall Accuracy: 0.98001998001998
#
# Class - Proliferative DR
#   Sensitivity: 0.0
#   Specificity: 1.0
#   Precision: 0.0
#   Negative Predictive Value: 0.975024975024975
#   False Positive Rate: 0.0
#   False Negative Rate: 1.0
#   False Discovery Rate: 0.0
#   Overall Accuracy: 0.975024975024975

# %%
# Metrics to plot
metrics = [TPR, TNR, PPV, NPV, FPR, FNR, FDR, ACC]
metric_names = ['Sensitivity', 'Specificity', 'Precision', 'NPV', 'FPR', 'FNR', 'FDR', 'Accuracy']

# Plotting
fig, axes = plt.subplots(4, 2, figsize=(10, 15))  # Adjust the size as needed
axes = axes.ravel()

for i, ax in enumerate(axes):
    ax.bar(class_names, metrics[i], color='skyblue')
    ax.set_title(metric_names[i])
    ax.set_ylim(0, 1)  # Assuming metrics are between 0 and 1
    ax.set_ylabel('Value')
    ax.set_xticklabels(class_names, rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-53-86800b8bc2b8>:14: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
class_labels = class_names

plt.figure(figsize=(10, 7))

# Create a heatmap
sns.heatmap(epconf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
